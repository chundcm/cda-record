# %% [markdown]
# # Sankey（桑基图）

# %% [markdown]
# 桑基图是一种特殊的流图, 它主要用来表示原材料、能量等如何从初始形式经过中间过程的加工、转化到达最终形式。

# %%
# 导入桑基图类
from pyecharts import Sankey

# %%
nodes = [
    {'name': '自己申请'}, {'name': '朋友推荐'}, {'name': '参加招聘会'},
    {'name': '上海'}, {'name': '南京'}, {'name': '杭州'},
    {'name': '面试'}, 
    {'name': '录用'}, {'name': '无响应'}, {'name': '拒绝'}
]

links = [
    {'source': '自己申请', 'target': '上海', 'value': 15},
    {'source': '自己申请', 'target': '南京', 'value': 15},
    {'source': '朋友推荐', 'target': '南京', 'value': 5},
    {'source': '自己申请', 'target': '杭州', 'value': 10},
    {'source': '参加招聘会', 'target': '杭州', 'value': 8},
    
    {'source': '上海', 'target': '无响应', 'value': 15},
    
    {'source': '南京', 'target': '无响应', 'value': 10},
    {'source': '南京', 'target': '面试', 'value': 10},
       
    {'source': '杭州', 'target': '无响应', 'value': 10},
    {'source': '杭州', 'target': '面试', 'value': 8},
    
    {'source': '面试', 'target': '录用', 'value': 5},
    {'source': '面试', 'target': '拒绝', 'value': 13}
]
sankey = Sankey("王小二找工作", width=1000, height=600)
sankey.add("", nodes, links,
           line_opacity=0.3,
           line_curve=0.5,
           line_color='source',
           is_random=True,
           is_label_show=True, label_pos='right')
# sankey.render()
sankey
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f6c9186f56c64bdb88c7baa21acf5dee" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f6c9186f56c64bdb88c7baa21acf5dee = echarts.init(document.getElementById('f6c9186f56c64bdb88c7baa21acf5dee'), 'light', {renderer: 'canvas'});
#
# var option_f6c9186f56c64bdb88c7baa21acf5dee = {
#     "color": [
#         "#ca8622",
#         "#61a0a8",
#         "#2f4554",
#         "#ac6767",
#         "#2a5caa",
#         "#c23531",
#         "#726930",
#         "#444693",
#         "#1d953f",
#         "#546570",
#         "#ef5b9c",
#         "#c4ccd3",
#         "#6950a1",
#         "#b2d235",
#         "#f6f5ec",
#         "#d48265",
#         "#905a3d",
#         "#6d8346",
#         "#f05b72",
#         "#918597",
#         "#6e7074",
#         "#fab27b",
#         "#749f83",
#         "#bda29a",
#         "#f47920"
#     ],
#     "title": [
#         {
#             "text": "\u738b\u5c0f\u4e8c\u627e\u5de5\u4f5c",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "show": true,
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "left": "center",
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "orient": "horizontal"
#         }
#     ],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderColor": "#333",
#         "trigger": "item"
#     },
#     "toolbox": {
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "left": "95%",
#         "show": true,
#         "top": "center",
#         "orient": "vertical"
#     },
#     "series": [
#         {
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "right",
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "type": "sankey",
#             "nodeWidth": 20,
#             "data": [
#                 {
#                     "name": "\u81ea\u5df1\u7533\u8bf7"
#                 },
#                 {
#                     "name": "\u670b\u53cb\u63a8\u8350"
#                 },
#                 {
#                     "name": "\u53c2\u52a0\u62db\u8058\u4f1a"
#                 },
#                 {
#                     "name": "\u4e0a\u6d77"
#                 },
#                 {
#                     "name": "\u5357\u4eac"
#                 },
#                 {
#                     "name": "\u676d\u5dde"
#                 },
#                 {
#                     "name": "\u9762\u8bd5"
#                 },
#                 {
#                     "name": "\u5f55\u7528"
#                 },
#                 {
#                     "name": "\u65e0\u54cd\u5e94"
#                 },
#                 {
#                     "name": "\u62d2\u7edd"
#                 }
#             ],
#             "lineStyle": {
#                 "normal": {
#                     "color": "source",
#                     "opacity": 0.3,
#                     "curveness": 0.5,
#                     "type": "solid",
#                     "width": 1
#                 }
#             },
#             "nodeGap": 8,
#             "links": [
#                 {
#                     "target": "\u4e0a\u6d77",
#                     "source": "\u81ea\u5df1\u7533\u8bf7",
#                     "value": 15
#                 },
#                 {
#                     "target": "\u5357\u4eac",
#                     "source": "\u81ea\u5df1\u7533\u8bf7",
#                     "value": 15
#                 },
#                 {
#                     "target": "\u5357\u4eac",
#                     "source": "\u670b\u53cb\u63a8\u8350",
#                     "value": 5
#                 },
#                 {
#                     "target": "\u676d\u5dde",
#                     "source": "\u81ea\u5df1\u7533\u8bf7",
#                     "value": 10
#                 },
#                 {
#                     "target": "\u676d\u5dde",
#                     "source": "\u53c2\u52a0\u62db\u8058\u4f1a",
#                     "value": 8
#                 },
#                 {
#                     "target": "\u65e0\u54cd\u5e94",
#                     "source": "\u4e0a\u6d77",
#                     "value": 15
#                 },
#                 {
#                     "target": "\u65e0\u54cd\u5e94",
#                     "source": "\u5357\u4eac",
#                     "value": 10
#                 },
#                 {
#                     "target": "\u9762\u8bd5",
#                     "source": "\u5357\u4eac",
#                     "value": 10
#                 },
#                 {
#                     "target": "\u65e0\u54cd\u5e94",
#                     "source": "\u676d\u5dde",
#                     "value": 10
#                 },
#                 {
#                     "target": "\u9762\u8bd5",
#                     "source": "\u676d\u5dde",
#                     "value": 8
#                 },
#                 {
#                     "target": "\u5f55\u7528",
#                     "source": "\u9762\u8bd5",
#                     "value": 5
#                 },
#                 {
#                     "target": "\u62d2\u7edd",
#                     "source": "\u9762\u8bd5",
#                     "value": 13
#                 }
#             ]
#         }
#     ],
#     "series_id": 5940873
# };
# myChart_f6c9186f56c64bdb88c7baa21acf5dee.setOption(option_f6c9186f56c64bdb88c7baa21acf5dee);
#
#     });
# </script>

# %%
import os
import json

from pyecharts import Sankey

with open("sankey.json", "r", encoding="utf-8") as f:
    j = json.load(f)

# %%
type(j)
# Out:
# dict

# %%
sankey = Sankey("桑基图示例", width=1200, height=600)
sankey.add("", nodes=j['nodes'], links=j['links'],
           line_opacity=0.2, line_curve=0.5, line_color='source',
           is_label_show=True, label_pos='right')
# sankey.render()
sankey
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c9e070c481454582a4024698984ab30e" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c9e070c481454582a4024698984ab30e = echarts.init(document.getElementById('c9e070c481454582a4024698984ab30e'), 'light', {renderer: 'canvas'});
#
# var option_c9e070c481454582a4024698984ab30e = {
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "top": "top",
#             "show": true,
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "left": "center",
#             "data": [
#                 ""
#             ]
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto",
#             "text": "\u6851\u57fa\u56fe\u793a\u4f8b",
#             "left": "auto"
#         }
#     ],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "toolbox": {
#         "show": true,
#         "top": "center",
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             }
#         }
#     },
#     "series": [
#         {
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "curveness": 0.5,
#                     "opacity": 0.2,
#                     "type": "solid",
#                     "color": "source"
#                 }
#             },
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "data": [
#                 {
#                     "name": "Agricultural 'waste'"
#                 },
#                 {
#                     "name": "Bio-conversion"
#                 },
#                 {
#                     "name": "Liquid"
#                 },
#                 {
#                     "name": "Losses"
#                 },
#                 {
#                     "name": "Solid"
#                 },
#                 {
#                     "name": "Gas"
#                 },
#                 {
#                     "name": "Biofuel imports"
#                 },
#                 {
#                     "name": "Biomass imports"
#                 },
#                 {
#                     "name": "Coal imports"
#                 },
#                 {
#                     "name": "Coal"
#                 },
#                 {
#                     "name": "Coal reserves"
#                 },
#                 {
#                     "name": "District heating"
#                 },
#                 {
#                     "name": "Industry"
#                 },
#                 {
#                     "name": "Heating and cooling - commercial"
#                 },
#                 {
#                     "name": "Heating and cooling - homes"
#                 },
#                 {
#                     "name": "Electricity grid"
#                 },
#                 {
#                     "name": "Over generation / exports"
#                 },
#                 {
#                     "name": "H2 conversion"
#                 },
#                 {
#                     "name": "Road transport"
#                 },
#                 {
#                     "name": "Agriculture"
#                 },
#                 {
#                     "name": "Rail transport"
#                 },
#                 {
#                     "name": "Lighting & appliances - commercial"
#                 },
#                 {
#                     "name": "Lighting & appliances - homes"
#                 },
#                 {
#                     "name": "Gas imports"
#                 },
#                 {
#                     "name": "Ngas"
#                 },
#                 {
#                     "name": "Gas reserves"
#                 },
#                 {
#                     "name": "Thermal generation"
#                 },
#                 {
#                     "name": "Geothermal"
#                 },
#                 {
#                     "name": "H2"
#                 },
#                 {
#                     "name": "Hydro"
#                 },
#                 {
#                     "name": "International shipping"
#                 },
#                 {
#                     "name": "Domestic aviation"
#                 },
#                 {
#                     "name": "International aviation"
#                 },
#                 {
#                     "name": "National navigation"
#                 },
#                 {
#                     "name": "Marine algae"
#                 },
#                 {
#                     "name": "Nuclear"
#                 },
#                 {
#                     "name": "Oil imports"
#                 },
#                 {
#                     "name": "Oil"
#                 },
#                 {
#                     "name": "Oil reserves"
#                 },
#                 {
#                     "name": "Other waste"
#                 },
#                 {
#                     "name": "Pumped heat"
#                 },
#                 {
#                     "name": "Solar PV"
#                 },
#                 {
#                     "name": "Solar Thermal"
#                 },
#                 {
#                     "name": "Solar"
#                 },
#                 {
#                     "name": "Tidal"
#                 },
#                 {
#                     "name": "UK land based bioenergy"
#                 },
#                 {
#                     "name": "Wave"
#                 },
#                 {
#                     "name": "Wind"
#                 }
#             ],
#             "links": [
#                 {
#                     "target": 1,
#                     "value": 124.729,
#                     "source": 0
#                 },
#                 {
#                     "target": 2,
#                     "value": 0.597,
#                     "source": 1
#                 },
#                 {
#                     "target": 3,
#                     "value": 26.862,
#                     "source": 1
#                 },
#                 {
#                     "target": 4,
#                     "value": 280.322,
#                     "source": 1
#                 },
#                 {
#                     "target": 5,
#                     "value": 81.144,
#                     "source": 1
#                 },
#                 {
#                     "target": 2,
#                     "value": 35,
#                     "source": 6
#                 },
#                 {
#                     "target": 4,
#                     "value": 35,
#                     "source": 7
#                 },
#                 {
#                     "target": 9,
#                     "value": 11.606,
#                     "source": 8
#                 },
#                 {
#                     "target": 9,
#                     "value": 63.965,
#                     "source": 10
#                 },
#                 {
#                     "target": 4,
#                     "value": 75.571,
