# %% [markdown]
# # Boxplot(箱线图)

# %% [markdown]
# 箱形图是一种用作显示一组数据分散情况资料的统计图。它能显示出一组数据的最大值、最小值、中位数、下四分位数及上四分位数。

# %%
from pyecharts import Boxplot

boxplot = Boxplot("箱形图")
x_axis = ['expr1', 'expr2', 'expr3', 'expr4', 'expr5']
y_axis = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880,1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840,830, 790, 810, 880, 880, 830, 800, 790, 760, 800],
    [880, 880, 880, 860, 720, 720, 620, 860, 970, 950,880, 910, 850, 870, 840, 840, 850, 840, 840, 840],
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760,910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850,870, 870, 810, 740, 810, 940, 950, 800, 810, 870]
]
_yaxis = boxplot.prepare_data(y_axis)       # 转换数据
boxplot.add("boxplot", x_axis, _yaxis)
boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4b79b5b334104e70828092e5d0b56128" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4b79b5b334104e70828092e5d0b56128 = echarts.init(document.getElementById('4b79b5b334104e70828092e5d0b56128'), 'light', {renderer: 'canvas'});
#
# var option_4b79b5b334104e70828092e5d0b56128 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u7bb1\u5f62\u56fe"
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "orient": "horizontal",
#             "show": true,
#             "selectedMode": "multiple",
#             "top": "top",
#             "data": [
#                 "boxplot"
#             ]
#         }
#     ],
#     "series_id": 8750498,
#     "xAxis": [
#         {
#             "splitLine": {
#                 "show": false
#             },
#             "type": "category",
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "inverse": false,
#             "data": [
#                 "expr1",
#                 "expr2",
#                 "expr3",
#                 "expr4",
#                 "expr5"
#             ],
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "nameGap": 25
#         }
#     ],
#     "yAxis": [
#         {
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value",
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "inverse": false,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "nameGap": 25
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0
#     },
#     "toolbox": {
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "series": [
#         {
#             "seriesId": 8750498,
#             "markPoint": {
#                 "data": []
#             },
#             "name": "boxplot",
#             "markLine": {
#                 "data": []
#             },
#             "type": "boxplot",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ],
#                 [
#                     620,
#                     840.0,
#                     855.0,
#                     880.0,
#                     970
#                 ],
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ]
#         }
#     ]
# };
# myChart_4b79b5b334104e70828092e5d0b56128.setOption(option_4b79b5b334104e70828092e5d0b56128);
#
#     });
# </script>

# %%
from pyecharts import Boxplot

boxplot = Boxplot("箱形图")
x_axis = ['expr1', 'expr2']
y_axis1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880,1000, 980, 930, 650, 760, 810, 1000, 1000, 960, 960],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840,830, 790, 810, 880, 880, 830, 800, 790, 760, 800]]
y_axis2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760,910, 920, 890, 860, 880, 720, 840, 850, 850, 780],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850,870, 870, 810, 740, 810, 940, 950, 800, 810, 870]]
boxplot.add("category1", x_axis, boxplot.prepare_data(y_axis1))
boxplot.add("category2", x_axis, boxplot.prepare_data(y_axis2))
boxplot
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4ab7d1f62cea4e77bf7f5d7247bb663f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4ab7d1f62cea4e77bf7f5d7247bb663f = echarts.init(document.getElementById('4ab7d1f62cea4e77bf7f5d7247bb663f'), 'light', {renderer: 'canvas'});
#
# var option_4ab7d1f62cea4e77bf7f5d7247bb663f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "xAxis": [
#         {
#             "splitLine": {
#                 "show": false
#             },
#             "type": "category",
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "inverse": false,
#             "data": [
#                 "expr1",
#                 "expr2"
#             ],
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "nameGap": 25
#         }
#     ],
#     "series": [
#         {
#             "seriesId": 5951234,
#             "markPoint": {
#                 "data": []
#             },
#             "name": "category1",
#             "markLine": {
#                 "data": []
#             },
#             "type": "boxplot",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 [
#                     650,
#                     850.0,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     760,
#                     800.0,
#                     845.0,
#                     895.0,
#                     960
#                 ]
#             ]
#         },
#         {
#             "seriesId": 5951234,
#             "markPoint": {
#                 "data": []
#             },
#             "name": "category2",
#             "markLine": {
#                 "data": []
#             },
#             "type": "boxplot",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "data": [
#                 [
#                     720,
#                     762.5,
#                     815.0,
#                     875.0,
#                     920
#                 ],
#                 [
#                     740,
#                     802.5,
#                     810.0,
#                     870.0,
#                     950
#                 ]
#             ]
#         }
#     ],
#     "series_id": 5951234,
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "text": "\u7bb1\u5f62\u56fe"
#         }
#     ],
#     "yAxis": [
#         {
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value",
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "inverse": false,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "nameGap": 25
#         }
#     ],
#     "tooltip": {
#         "borderColor": "#333",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "triggerOn": "mousemove|click",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0
#     },
#     "toolbox": {
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center",
#         "orient": "vertical"
#     },
#     "legend": [
#         {
#             "left": "center",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "orient": "horizontal",
#             "show": true,
#             "selectedMode": "multiple",
#             "top": "top",
#             "data": [
#                 "category1",
#                 "category2"
#             ]
#         }
#     ]
# };
# myChart_4ab7d1f62cea4e77bf7f5d7247bb663f.setOption(option_4ab7d1f62cea4e77bf7f5d7247bb663f);
#
#     });
# </script>
