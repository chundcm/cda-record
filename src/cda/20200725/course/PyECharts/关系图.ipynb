# %% [markdown]
# # Graph(关系图)

# %% [markdown]
# 用于展现节点以及节点之间的关系数据。

# %%
# 导入pyecharts
import pyecharts
# 检查pyecharts版本
pyecharts.__version__
# Out:
# '0.5.5'

# %%
# 导入关系图类
from pyecharts import Graph

# %% [markdown]
# ### 模拟微信好友社会关系，并绘图

# %%
# 节点
nodes = [{'name': '童秀云', "symbolSize": 12,"category": 0,
          'symbol': 'markPoint','value': 2},
         {'name': '武淑珍', "symbolSize": 12,
          'label': {'normal': {'show': True,'textStyle': {'fontSize': 18},}},
          "category": 0,'value': 2,},
         {'name': '文华', "symbolSize": 25, 'draggable': True,"category": 0,'value': 3},
         {'name': '冉坤', "symbolSize": 25, 'draggable': True,"category": 1,'value': 3},
         {'name': '雕志强', "symbolSize": 12, 'draggable': True,"category": 1,'value': 2},
         {'name': '焦超', "symbolSize": 8, 'draggable': True,"category": 1,'value': 0},
        ]

# %%
# 关系
links = [{'source': '童秀云','target': '冉坤','value': '夫妻',
          'lineStyle': {'normal': {'color': 'red', 
                                   'type': 'dotted',  # 点线
                                  }}},
         {'source': '文华','target': '武淑珍', 'value': '朋友',
          'lineStyle': { 'normal': {'opacity': 0.9,  # 透明度
                                    'width': 1,
                                    'curveness': 0.1  # 弯曲程度
                                   }}},
         {'source': '童秀云','target': '文华','value': '同事'},
         {'source': '雕志强','target': '文华','value': '夫妻'},
         {'source': '武淑珍','target': '冉坤','value': '朋友'},
         {'source': '雕志强','target': '冉坤','value': '同事'}
        ]

# %%
# 绘图
graph = Graph("微信好友社会关系图", width=500, height=250)
graph.add("姓名", nodes, links, [0,1],
          is_label_show=True,
          label_pos="right",
          graph_repulsion=500,  # 节点之间的斥力因子。默认为 50
#           graph_layout='circular',  # 采用环形布局
          graph_layout='force',  # 采用力引导布局
          label_text_color=None,
         is_rotatelabel=True,  # 是否旋转标签，默认为 False
#           is_roam=False,  #  是否开启鼠标缩放和平移漫游。默认为 True
          is_legend_show=True,
         )
# 保存
# graph.render()
# graph.render(path='微信好友社会关系图.html')
# 展示
graph
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="84bf6d4dac29419899bf1dba979f782a" style="width:500px;height:250px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_84bf6d4dac29419899bf1dba979f782a = echarts.init(document.getElementById('84bf6d4dac29419899bf1dba979f782a'), 'light', {renderer: 'canvas'});
#
# var option_84bf6d4dac29419899bf1dba979f782a = {
#     "series_id": 1008642,
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         }
#     },
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "data": [
#                 0,
#                 1
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "orient": "horizontal",
#             "left": "center"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "roam": true,
#             "symbol": "circle",
#             "layout": "force",
#             "data": [
#                 {
#                     "category": 0,
#                     "name": "\u7ae5\u79c0\u4e91",
#                     "value": 2,
#                     "symbolSize": 12,
#                     "symbol": "markPoint"
#                 },
#                 {
#                     "category": 0,
#                     "name": "\u6b66\u6dd1\u73cd",
#                     "value": 2,
#                     "symbolSize": 12,
#                     "label": {
#                         "normal": {
#                             "textStyle": {
#                                 "fontSize": 18
#                             },
#                             "show": true
#                         }
#                     }
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u6587\u534e",
#                     "value": 3,
#                     "symbolSize": 25
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u5189\u5764",
#                     "value": 3,
#                     "symbolSize": 25
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u96d5\u5fd7\u5f3a",
#                     "value": 2,
#                     "symbolSize": 12
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u7126\u8d85",
#                     "value": 0,
#                     "symbolSize": 8
#                 }
#             ],
#             "circular": {
#                 "rotateLabel": true
#             },
#             "name": "\u59d3\u540d",
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "color": "#aaa",
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true,
#                     "position": "right"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "type": "graph",
#             "force": {
#                 "edgeLength": 50,
#                 "gravity": 0.2,
#                 "repulsion": 500
#             },
#             "focusNodeAdjacency": true,
#             "edgeSymbolSize": 10,
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "links": [
#                 {
#                     "value": "\u592b\u59bb",
#                     "lineStyle": {
#                         "normal": {
#                             "color": "red",
#                             "type": "dotted"
#                         }
#                     },
#                     "target": "\u5189\u5764",
#                     "source": "\u7ae5\u79c0\u4e91"
#                 },
#                 {
#                     "value": "\u670b\u53cb",
#                     "lineStyle": {
#                         "normal": {
#                             "opacity": 0.9,
#                             "width": 1,
#                             "curveness": 0.1
#                         }
#                     },
#                     "target": "\u6b66\u6dd1\u73cd",
#                     "source": "\u6587\u534e"
#                 },
#                 {
#                     "value": "\u540c\u4e8b",
#                     "target": "\u6587\u534e",
#                     "source": "\u7ae5\u79c0\u4e91"
#                 },
#                 {
#                     "value": "\u592b\u59bb",
#                     "target": "\u6587\u534e",
#                     "source": "\u96d5\u5fd7\u5f3a"
#                 },
#                 {
#                     "value": "\u670b\u53cb",
#                     "target": "\u5189\u5764",
#                     "source": "\u6b66\u6dd1\u73cd"
#                 },
#                 {
#                     "value": "\u540c\u4e8b",
#                     "target": "\u5189\u5764",
#                     "source": "\u96d5\u5fd7\u5f3a"
#                 }
#             ],
#             "categories": [
#                 0,
#                 1
#             ]
#         }
#     ],
#     "title": [
#         {
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "text": "\u5fae\u4fe1\u597d\u53cb\u793e\u4f1a\u5173\u7cfb\u56fe"
#         }
#     ]
# };
# myChart_84bf6d4dac29419899bf1dba979f782a.setOption(option_84bf6d4dac29419899bf1dba979f782a);
#
#     });
# </script>

# %% [markdown]
# ## 吸毒人员社会关系图(模拟数据)

# %% [markdown]
# #### 模拟数据

# %%
import random
random.seed(1026)

# faker 包可以用来生成模拟数据
from faker import Faker
fake = Faker()
fake = Faker('zh_CN')  # 中文简体
# fake = Faker('en')   # 英文

# %%
# 生成节点初始数据
num = 80  # 设置姓名数， 可能有重名，所以不一定等于节点数
nodes = []
for _ in range(0, num):
    nodes.append(({'name': fake.name(),
                   'category': random.choice([1, 0]),  # random category
                   'draggable': True}))

# %%
# 唯一姓名数
names = set()
for node in nodes:
    names.add(node.get('name'))
names = list(names)
print('共随机生成{}个人，前5个是：\n{}'.format(len(names), names[:5]))
# Out:
# 共随机生成80个人，前5个是：
# ['居利', '佘琴', '贲博', '洪军', '蔡慧']

# %%
# 生成节点关系数据
links = []
for _ in range(0, num*2):
    names_tmp = names.copy()
    name = random.choice(names_tmp)
    names_tmp.remove(name)
    target = random.choice(names_tmp)
    j = 1
    for link in links:
        for k, v in link.items():
            if (k==name and v==target) or (v==name and k==target):
                j = 0
    if j:  # 删除重复关系对
        links.append(({'source': name,
                       'target': target,
                       'value': random.choice(["夫妻", "同事", "朋友", "亲戚", "同学"])}))
print('共随机生成{}对关系，前5对是：\n{}'.format(len(links), links[:5]))
# Out:
# 共随机生成160对关系，前5对是：
# [{'value': '同事', 'target': '金琳', 'source': '詹玲'}, {'value': '亲戚', 'target': '詹金凤', 'source': '农淑华'}, {'value': '夫妻', 'target': '伍洋', 'source': '贾帅'}, {'value': '朋友', 'target': '贲博', 'source': '阙芳'}, {'value': '亲戚', 'target': '蔡慧', 'source': '贺秀荣'}]

# %%
# 计算关系
connections = {}
# source to target
names2 = set()
for link in links:
    names2.add(link.get('source'))
for name in names2:
    c = 0
    for _ in links:
        if _.get('source') == name:
            c += 1
    connections[name] = c
# connections

# %%
# target to source
names3 = set()
for link in links:
    names3.add(link.get('target'))
for name in names3:
    c = 0
    for _ in links:
        if _.get('target') == name:
            c += 1
    if connections.get(name):
        connections[name] += c
    else:
        connections[name] = c
# print(connections)

# %%
# 添加关系数和节点大小参数到节点中
for node in nodes:
    for name, value in connections.items():
        if node.get('name') == name:
            node['value'] = value
            node['symbolSize'] = value * 4 + 5

# %%
from pyecharts import Graph

graph = Graph("吸毒人员社会关系图", "模拟数据", width=1100, height=700)
graph.add("姓名：",  # 提示框名称
          nodes,  # 节点数据
          links,  # 结点间的关系数据
          categories=[0, 1],  # 结点分类的类目，结点可以指定分类，也可以不指定
          is_label_show=True,  # 是否显示节点标签
          label_pos="top",  # 节点标签位置
          graph_repulsion=180,  # 节点之间的斥力因子。默认为 50
#           graph_layout='circular',  # 采用环形布局
          graph_layout='force',  # 采用力引导布局
          label_text_color=None,
          is_rotatelabel=True,  # 是否旋转标签，默认为 False
#           is_roam=False,  #  是否开启鼠标缩放和平移漫游。默认为 True
         )
graph.render(path='吸毒人员社会关系图（模拟数据）.html')
graph
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="38c25d81dc2d4e77ad3ec5e70987b11a" style="width:1100px;height:700px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_38c25d81dc2d4e77ad3ec5e70987b11a = echarts.init(document.getElementById('38c25d81dc2d4e77ad3ec5e70987b11a'), 'light', {renderer: 'canvas'});
#
# var option_38c25d81dc2d4e77ad3ec5e70987b11a = {
#     "series_id": 5707799,
#     "toolbox": {
#         "top": "center",
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         }
#     },
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "trigger": "item",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "data": [
#                 0,
#                 1
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "orient": "horizontal",
#             "left": "center"
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "roam": true,
#             "symbol": "circle",
#             "layout": "force",
#             "data": [
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u7763\u6dd1\u82f1",
#                     "value": 2,
#                     "symbolSize": 13
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u9633\u534e",
#                     "value": 5,
#                     "symbolSize": 25
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u677e\u7ea2",
#                     "value": 4,
#                     "symbolSize": 21
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u5c45\u5229",
#                     "value": 3,
#                     "symbolSize": 17
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u7b80\u65ed",
#                     "value": 6,
#                     "symbolSize": 29
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u5468\u7433",
#                     "value": 1,
#                     "symbolSize": 9
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u71d5\u519b",
#                     "value": 3,
#                     "symbolSize": 17
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u8d32\u535a",
#                     "value": 10,
#                     "symbolSize": 45
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u66b4\u8f89",
#                     "value": 5,
#                     "symbolSize": 25
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u6d2a\u519b",
#                     "value": 4,
#                     "symbolSize": 21
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u4ea2\u60f3",
#                     "value": 1,
#                     "symbolSize": 9
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u84dd\u5a77\u5a77",
#                     "value": 6,
#                     "symbolSize": 29
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u547c\u7389\u82f1",
#                     "value": 1,
#                     "symbolSize": 9
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u8a79\u73b2",
#                     "value": 5,
#                     "symbolSize": 25
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u987e\u96ea",
#                     "value": 3,
#                     "symbolSize": 17
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u4e30\u65ed",
#                     "value": 1,
#                     "symbolSize": 9
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u516c\u82b3",
#                     "value": 8,
#                     "symbolSize": 37
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u7b26\u946b",
#                     "value": 2,
#                     "symbolSize": 13
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u9619\u82b3",
#                     "value": 4,
#                     "symbolSize": 21
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u8521\u6167",
#                     "value": 5,
#                     "symbolSize": 25
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u5bbf\u6b23",
#                     "value": 2,
#                     "symbolSize": 13
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u4e07\u535a",
#                     "value": 6,
#                     "symbolSize": 29
#                 },
#                 {
#                     "draggable": true,
#                     "category": 0,
#                     "name": "\u5e38\u521a",
#                     "value": 2,
#                     "symbolSize": 13
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u961a\u6842\u82b1",
#                     "value": 7,
#                     "symbolSize": 33
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u6c5d\u4f1f",
#                     "value": 2,
#                     "symbolSize": 13
#                 },
#                 {
#                     "draggable": true,
#                     "category": 1,
#                     "name": "\u81e7\u5fd7\u5f3a",
