# %% [markdown]
# # Line（折线/面积图）

# %% [markdown]
# 折线图是用折线将各个数据点标志连接起来的图表，用于展现数据的变化趋势。

# %%
from pyecharts import Line

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [5, 20, 36, 10, 10, 100]
v2 = [55, 60, 16, 20, 15, 80]

line = Line("折线图示例")
line.add("商家A", attr, v1, mark_point=["average"])
line.add("商家B", attr, v2, is_smooth=True, mark_line=["max", "average"])
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5e3af1faa1ba40cab8c1fb3a453095e6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5e3af1faa1ba40cab8c1fb3a453095e6 = echarts.init(document.getElementById('5e3af1faa1ba40cab8c1fb3a453095e6'), 'light', {renderer: 'canvas'});
#
# var option_5e3af1faa1ba40cab8c1fb3a453095e6 = {
#     "series_id": 1943481,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
# ...

# %%
line = Line("折线图示例")
line.add("商家A", attr, v1, mark_point=["average", "max", "min"],
         mark_point_symbol='diamond', mark_point_textcolor='#FFB90F')
line.add("商家B", attr, v2, mark_point=["average", "max", "min"],
         mark_point_symbol='arrow', mark_point_symbolsize=40)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="60416be7c8af4ce892e39d302952c92b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_60416be7c8af4ce892e39d302952c92b = echarts.init(document.getElementById('60416be7c8af4ce892e39d302952c92b'), 'light', {renderer: 'canvas'});
#
# var option_60416be7c8af4ce892e39d302952c92b = {
#     "series_id": 388875,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
# ...

# %%
line = Line("折线图示例")
line.add("商家A", attr, v1,
            mark_point=["average", {
                "coord": ["裤子", 10], "name": "这是我想要的第一个标记点"}])
line.add("商家B", attr, v2, is_smooth=False,
            mark_point=[{
                "coord": ["袜子", 80], "name": "这是我想要的第二个标记点"}])
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="82a6125d50414621bf433b18e3e7a505" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_82a6125d50414621bf433b18e3e7a505 = echarts.init(document.getElementById('82a6125d50414621bf433b18e3e7a505'), 'light', {renderer: 'canvas'});
#
# var option_82a6125d50414621bf433b18e3e7a505 = {
#     "series_id": 6082300,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
# ...

# %%
line = Line("折线图-数据堆叠示例")
line.add("商家A", attr, v1, is_stack=True, is_label_show=True)
line.add("商家B", attr, v2, is_stack=True, is_label_show=True)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4f148660a64649f18174d50faeff101d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4f148660a64649f18174d50faeff101d = echarts.init(document.getElementById('4f148660a64649f18174d50faeff101d'), 'light', {renderer: 'canvas'});
#
# var option_4f148660a64649f18174d50faeff101d = {
#     "series_id": 68094,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
# ...

# %% [markdown]
# 阶梯图

# %%
line = Line("折线图-阶梯图示例")
line.add("商家A", attr, v1, is_step=True, is_label_show=True)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b8785eeb9c3d44d792568b10aa373523" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b8785eeb9c3d44d792568b10aa373523 = echarts.init(document.getElementById('b8785eeb9c3d44d792568b10aa373523'), 'light', {renderer: 'canvas'});
#
# var option_b8785eeb9c3d44d792568b10aa373523 = {
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
# ...

# %%
import pandas as pd
from pyecharts import Line

months = pd.DataFrame(pd.date_range('11/1/2016', '4/1/2018', freq='M'), columns=['Date'])
months['YearMonth'] = months['Date'].apply(lambda x:x.strftime('%Y-%m'))

# %%
value = [54986,54946,54931,54778,54730,54619,54512,54492,54446,54382,54314,54288,54278,54256,54240,54191,54185]
line = Line("深圳近年新房均价走势图", "单位：元/m2 数据来源：深圳房地产信息网数据中心", width=1000)
line.add("新房均价", months['YearMonth'], value, is_smooth=True, xaxis_rotate=40)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="17b31d63817f42418f3967da13a9f50a" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_17b31d63817f42418f3967da13a9f50a = echarts.init(document.getElementById('17b31d63817f42418f3967da13a9f50a'), 'light', {renderer: 'canvas'});
#
# var option_17b31d63817f42418f3967da13a9f50a = {
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
# ...

# %%
import pandas as pd
from pyecharts import Line

line = Line("深圳近年新房均价走势图", "单位：元/m2 数据来源：深圳房地产信息网数据中心", width=1000)
line.add("新房均价", months['YearMonth'], value,
#          mark_point=["average"],
         is_label_show=True,
         is_smooth=True,
         xaxis_rotate=30,
         yaxis_min=54100, yaxis_max=55000,
#          yaxis_interval=200,
         yaxis_force_interval=100,
        )
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e00ba33f67944056875199edd385a761" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e00ba33f67944056875199edd385a761 = echarts.init(document.getElementById('e00ba33f67944056875199edd385a761'), 'light', {renderer: 'canvas'});
#
# var option_e00ba33f67944056875199edd385a761 = {
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
# ...

# %%
index
# Out:
# DatetimeIndex(['2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31',
#                '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31',
#                '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30',
#                '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
#                '2018-02-28'],
#               dtype='datetime64[ns]', freq='M')

# %%
line = Line("折线图-面积图示例")
line.add("商家A", attr, v1, is_fill=True, line_opacity=0.9,
         area_opacity=0.4, symbol=None)
line.add("商家B", attr, v2, is_fill=True, area_color='#000',
         area_opacity=0.3, is_smooth=True)
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="33113fc7c38443528d739c43631b75c5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_33113fc7c38443528d739c43631b75c5 = echarts.init(document.getElementById('33113fc7c38443528d739c43631b75c5'), 'light', {renderer: 'canvas'});
#
# var option_33113fc7c38443528d739c43631b75c5 = {
#     "series_id": 8439236,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
# ...

# %%
import math, random
line = Line("折线图示例")
line.add("商家A", attr, [math.log10(random.randint(1, 99999)) for _ in range(6)])
line.add("商家B", attr, [math.log10(random.randint(1, 99999999)) for _ in range(6)],
         yaxis_type="log"
        )
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c72cd82b5d7f416a8a85fbdb79e8262c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c72cd82b5d7f416a8a85fbdb79e8262c = echarts.init(document.getElementById('c72cd82b5d7f416a8a85fbdb79e8262c'), 'light', {renderer: 'canvas'});
#
# var option_c72cd82b5d7f416a8a85fbdb79e8262c = {
#     "series_id": 6144153,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
# ...

# %%
from pyecharts import Line

attr = ['周一', '周二', '周三', '周四', '周五', '周六', '周日', ]
line = Line("折线图示例")
line.add("最高气温", attr, [11, 11, 15, 13, 12, 13, 10],
         mark_point=["max", "min"], mark_line=["average"])
line.add("最低气温", attr, [1, -2, 2, 5, 3, 2, 0],
         mark_point=["max", "min"],  mark_line=["average"],
         yaxis_formatter="°C"
        )
# line.show_config()
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2dd92506908d4dbc91d853424d032fe8" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2dd92506908d4dbc91d853424d032fe8 = echarts.init(document.getElementById('2dd92506908d4dbc91d853424d032fe8'), 'light', {renderer: 'canvas'});
#
# var option_2dd92506908d4dbc91d853424d032fe8 = {
#     "series_id": 5915209,
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
# ...

# %% [markdown]
# # Kline/Candlestick（K线图）

# %% [markdown]
# * 红涨蓝跌
# * 日K线图又称阴阳烛，最初是日本米商用来表示米价涨跌状况的工具，后来引入股市，并逐渐风行于东南亚地区。K线图以其直观、立体感强的特点而深受投资者欢迎。
# * 股市及期货市场中的K线图的画法包含四个数据，即开盘价、最高价、最低价、收盘价，所有的k线都是围绕这四个数据展开，反映大势的状况和价格信息。如果把每日的K线图放在一张纸上，就能得到日K线图，同样也可画出周K线图、月K线图。

# %% [markdown]
# 日K线图解：
# ![日K线图解](日K线图解.gif)

# %%
from pyecharts import Kline

# [open, close, lowest, highest]
v1 = [[2320.26, 2320.26, 2287.3, 2362.94], [2300, 2291.3, 2288.26, 2308.38],
      [2295.35, 2346.5, 2295.35, 2345.92], [2347.22, 2358.98, 2337.35, 2363.8],
      [2360.75, 2382.48, 2347.89, 2383.76], [2383.43, 2385.42, 2371.23, 2391.82],
      [2377.41, 2419.02, 2369.57, 2421.15], [2425.92, 2428.15, 2417.58, 2440.38],
      [2411, 2433.13, 2403.3, 2437.42], [2432.68, 2334.48, 2427.7, 2441.73],
      [2430.69, 2418.53, 2394.22, 2433.89], [2416.62, 2432.4, 2414.4, 2443.03],
      [2441.91, 2421.56, 2418.43, 2444.8], [2420.26, 2382.91, 2373.53, 2427.07],
      [2383.49, 2397.18, 2370.61, 2397.94], [2378.82, 2325.95, 2309.17, 2378.82],
      [2322.94, 2314.16, 2308.76, 2330.88], [2320.62, 2325.82, 2315.01, 2338.78],
      [2313.74, 2293.34, 2289.89, 2340.71], [2297.77, 2313.22, 2292.03, 2324.63],
      [2322.32, 2365.59, 2308.92, 2366.16], [2364.54, 2359.51, 2330.86, 2369.65],
      [2332.08, 2273.4, 2259.25, 2333.54], [2274.81, 2326.31, 2270.1, 2328.14],
      [2333.61, 2347.18, 2321.6, 2351.44], [2340.44, 2324.29, 2304.27, 2352.02],
      [2326.42, 2318.61, 2314.59, 2333.67], [2314.68, 2310.59, 2296.58, 2320.96],
      [2309.16, 2286.6, 2264.83, 2333.29], [2282.17, 2263.97, 2253.25, 2286.33],
      [2255.77, 2270.28, 2253.31, 2276.22]]
kline = Kline("K 线图示例")
kline.add("日K", ["2017/7/{}".format(i + 1) for i in range(31)], v1)
kline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="dd2d3eb1333042fea7e0da557a419d15" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_dd2d3eb1333042fea7e0da557a419d15 = echarts.init(document.getElementById('dd2d3eb1333042fea7e0da557a419d15'), 'light', {renderer: 'canvas'});
#
# var option_dd2d3eb1333042fea7e0da557a419d15 = {
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
# ...

# %% [markdown]
# 语法及参数
# * add(name, x_axis, y_axis, **kwargs)
#     * name -> str    图例名称
#     * x_axis -> list    x 坐标轴数据
#     * y_axis -> [list], 包含列表的列表    y 坐标轴数据。数据中，每一行是一个『数据项』，每一列属于一个『维度』。 数据项具体为 [open, close, lowest, highest] （即：[开盘值, 收盘值, 最低值, 最高值]）

# %%
kline = Kline("K 线图示例",width=1000)
kline.add("日K", ["2017/7/{}".format(i + 1) for i in range(31)], v1,
          mark_point=["max"], is_datazoom_show=True,
          datazoom_type='both',  # 区域缩放组件类型，默认为'slider'，有'slider', 'inside', 'both'可选
         )
kline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="66d1e093e60e446798b95512ff48ba09" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_66d1e093e60e446798b95512ff48ba09 = echarts.init(document.getElementById('66d1e093e60e446798b95512ff48ba09'), 'light', {renderer: 'canvas'});
#
# var option_66d1e093e60e446798b95512ff48ba09 = {
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
# ...

# %%
kline = Kline("K 线图示例", width=1000)
kline.add("日K", ["2017/7/{}".format(i + 1) for i in range(31)], v1,
          mark_point=["max"], 
#           mark_line=["max"], mark_line_symbolsize=0,
          is_datazoom_show=True,
          datazoom_orient='vertical',
         datazoom_range=[20,50],  # 区域缩放的范围，默认为[50, 100]
         )
kline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a3a0a01713294ab2bad0602e3498a76c" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a3a0a01713294ab2bad0602e3498a76c = echarts.init(document.getElementById('a3a0a01713294ab2bad0602e3498a76c'), 'light', {renderer: 'canvas'});
#
# var option_a3a0a01713294ab2bad0602e3498a76c = {
#     "toolbox": {
#         "left": "95%",
#         "show": true,
#         "orient": "vertical",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
# ...

# %%
import tushare as ts
kl_pa = ts.get_hist_data('000001',start='2018-04-01',end='2018-05-20') # 一次性获取全部日k线数据，平安银行
kl_pa.head()
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2018-05-18  10.81  10.97  10.96  10.76   578384.75          0.14      1.29
# 2018-05-17  10.91  10.94  10.82  10.78   586494.38         -0.08     -0.73
# 2018-05-16  11.07  11.07  10.90  10.89   714362.06         -0.22     -1.98
# 2018-05-15  11.18  11.19  11.12  11.02   669261.44         -0.06     -0.54
# 2018-05-14  11.09  11.23  11.18  11.03  1039297.12          0.17      1.54
#
#                ma5    ma10    ma20      v_ma5      v_ma10      v_ma20  \
# date
# 2018-05-18  10.996  10.979  11.115  717559.95   788817.68   986204.70
# 2018-05-17  11.006  10.951  11.142  756356.94   802030.15  1031077.73
# 2018-05-16  11.044  10.944  11.162  749605.24   871516.27  1066847.59
# 2018-05-15  11.058  10.942  11.172  732264.05   919132.39  1102483.12
# 2018-05-14  11.036  10.915  11.194  873072.89  1123185.82  1134032.85
#
#             turnover
# date
# 2018-05-18      0.34
# 2018-05-17      0.35
# ...

# %%
# kl_pa.iloc[:,[0,2,3,1]].values

# %%
kl_wk = ts.get_hist_data('000002',start='2018-04-01',end='2018-05-20') # 一次性获取全部日k线数据，万科Ａ股
kl_wk.head()
# Out:
#              open   high  close    low     volume  price_change  p_change  \
# date
# 2018-05-18  26.70  27.15  27.15  26.53  407222.28          0.36      1.34
# 2018-05-17  27.19  27.22  26.79  26.77  445623.88         -0.44     -1.62
# 2018-05-16  27.55  27.75  27.23  27.21  373238.09         -0.52     -1.87
# 2018-05-15  28.11  28.15  27.75  27.34  405069.28         -0.19     -0.68
# 2018-05-14  28.08  28.29  27.94  27.87  350838.56          0.00      0.00
#
#                ma5    ma10    ma20      v_ma5     v_ma10     v_ma20  turnover
# date
# 2018-05-18  27.372  27.714  28.365  396398.42  420323.74  417136.68      0.42
# 2018-05-17  27.530  27.690  28.510  378614.71  422139.87  413217.33      0.46
# 2018-05-16  27.786  27.744  28.666  375417.84  431819.46  403846.02      0.38
# 2018-05-15  27.980  27.789  28.806  382576.39  434212.73  411587.55      0.42
# 2018-05-14  28.168  27.854  28.981  432726.03  431901.63  408912.72      0.36

# %%
from pyecharts import Kline

kline = Kline("平安银行 vs. 万科Ａ股 日K线图", width=1000)
kline.add("平安银行", kl_pa.index, kl_pa.iloc[:,[0,2,3,1]].values,
          mark_point=["max"],
#           mark_line=["max"], mark_line_symbolsize=0,
          is_datazoom_show=True)
kline.add("万科Ａ股", kl_wk.index, kl_wk.iloc[:,[0,2,3,1]].values,
          mark_point=["max"],
#           mark_line=["max"], mark_line_symbolsize=0,
          is_datazoom_show=True)
kline
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="07fb632b8fa844a9bf03271e353b1b43" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_07fb632b8fa844a9bf03271e353b1b43 = echarts.init(document.getElementById('07fb632b8fa844a9bf03271e353b1b43'), 'light', {renderer: 'canvas'});
#
# var option_07fb632b8fa844a9bf03271e353b1b43 = {
#     "series_id": 7922621,
#     "xAxis": [
#         {
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "category",
#             "scale": true,
#             "axisLabel": {
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto"
#             },
# ...
