# %% [markdown]
# # Geo（地理坐标系）

# %% [markdown]
# 地理坐标系组件用于地图的绘制，支持在地理坐标系上绘制散点图，线图，热力图。

# %%
from pyecharts import Geo

data1 = [
    ("海门", 9),("鄂尔多斯", 12),("招远", 12),("舟山", 12),("齐齐哈尔", 14),("盐城", 15),
    ("赤峰", 16),("青岛", 18),("乳山", 18),("金昌", 19),("泉州", 21),("莱西", 21),
    ("日照", 21),("胶南", 22),("南通", 23),("拉萨", 24),("云浮", 24),("梅州", 25),
    ("文登", 25),("上海", 25),("攀枝花", 25),("威海", 25),("承德", 25),("厦门", 26),
    ("汕尾", 26),("潮州", 26),("丹东", 27),("太仓", 27),("曲靖", 27),("烟台", 28),
    ("福州", 29),("瓦房店", 30),("即墨", 30),("抚顺", 31),("玉溪", 31),("张家口", 31),
    ("阳泉", 31),("莱州", 32),("湖州", 32),("汕头", 32),("昆山", 33),("宁波", 33),
    ("湛江", 33),("揭阳", 34),("荣成", 34),("连云港", 35),("葫芦岛", 35),("常熟", 36),
    ("东莞", 36),("河源", 36),("淮安", 36),("泰州", 36),("南宁", 37),("营口", 37),
    ("惠州", 37),("江阴", 37),("蓬莱", 37),("韶关", 38),("嘉峪关", 38),("广州", 38),
    ("延安", 38),("太原", 39),("清远", 39),("中山", 39),("昆明", 39),("寿光", 40),
    ("盘锦", 40),("长治", 41),("深圳", 41),("珠海", 42),("宿迁", 43),("咸阳", 43),
    ("铜川", 44),("平度", 44),("佛山", 44),("海口", 44),("江门", 45),("章丘", 45),
    ("肇庆", 46),("大连", 47),("临汾", 47),("吴江", 47),("石嘴山", 49),("沈阳", 50),
    ("苏州", 50),("茂名", 50),("嘉兴", 51),("长春", 51),("胶州", 52),("银川", 52),
    ("张家港", 52),("三门峡", 53),("锦州", 54),("南昌", 54),("柳州", 54),("三亚", 54),
    ("自贡", 56),("吉林", 56),("阳江", 57),("泸州", 57),("西宁", 57),("宜宾", 58),
    ("呼和浩特", 58),("成都", 58),("大同", 58),("镇江", 59),("桂林", 59),("张家界", 59),
    ("宜兴", 59),("北海", 60),("西安", 61),("金坛", 62),("东营", 62),("牡丹江", 63),
    ("遵义", 63),("绍兴", 63),("扬州", 64),("常州", 64),("潍坊", 65),("重庆", 66),
    ("台州", 67),("南京", 67),("滨州", 70),("贵阳", 71),("无锡", 71),("本溪", 71),
    ("克拉玛依", 72),("渭南", 72),("马鞍山", 72),("宝鸡", 72),("焦作", 75),("句容", 75),
    ("北京", 79),("徐州", 79),("衡水", 80),("包头", 80),("绵阳", 80),("乌鲁木齐", 84),
    ("枣庄", 84),("杭州", 84),("淄博", 85),("鞍山", 86),("溧阳", 86),("库尔勒", 86),
    ("安阳", 90),("开封", 90),("济南", 92),("德阳", 93),("温州", 95),("九江", 96),
    ("邯郸", 98),("临安", 99),("兰州", 99),("沧州", 100),("临沂", 103),("南充", 104),
    ("天津", 105),("富阳", 106),("泰安", 112),("诸暨", 112),("郑州", 113),("哈尔滨", 114),
    ("聊城", 116),("芜湖", 117),("唐山", 119),("平顶山", 119),("邢台", 119),("德州", 120),
    ("济宁", 120),("荆州", 127),("宜昌", 130),("义乌", 132),("丽水", 133),("洛阳", 134),
    ("秦皇岛", 136),("株洲", 143),("石家庄", 147),("莱芜", 148),("常德", 152),("保定", 153),
    ("湘潭", 154),("金华", 157),("岳阳", 169),("长沙", 175),("衢州", 177),("廊坊", 193),
    ("菏泽", 194),("合肥", 229),("武汉", 273),("大庆", 279)]

geo = Geo("全国主要城市空气质量", "data from pm2.5", title_color="#fff",
          title_pos="center", width=1000, height=800,
          background_color='#404a59')
attr, value = geo.cast(data1)
geo.add("", attr, value,
#         maptype='china',
        visual_range=[0, 200], visual_text_color="#fff",
        symbol_size=12, is_visualmap=True)
# geo.show_config()
geo.render(path='全国主要城市空气质量.html')
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="548cc9162c124f29a58c01b3b0608f5d" style="width:1000px;height:800px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_548cc9162c124f29a58c01b3b0608f5d = echarts.init(document.getElementById('548cc9162c124f29a58c01b3b0608f5d'), 'light', {renderer: 'canvas'});
#
# var option_548cc9162c124f29a58c01b3b0608f5d = {
#     "series": [
#         {
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
# ...

# %%
from pyecharts import Geo

data2 = [("海门", 9), ("鄂尔多斯", 12), ("招远", 12), ("舟山", 12), ("齐齐哈尔", 14), ("盐城", 15),
        ("庆阳市",1),("南通市",3)]
geo = Geo("全国主要城市空气质量", "data from pm2.5", title_color="#fff", title_pos="center",
          width=1200, height=600, background_color='#404a59')
attr, value = geo.cast(data2)
geo.add("", attr, value, type="effectScatter", effect_scale=5, maptype='china',
       is_random=True)
# geo.show_config()
# geo.render(path='全国主要城市空气质量2.html')
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="7f9b215666b74ab0bd0e41b13038cc9e" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_7f9b215666b74ab0bd0e41b13038cc9e = echarts.init(document.getElementById('7f9b215666b74ab0bd0e41b13038cc9e'), 'light', {renderer: 'canvas'});
#
# var option_7f9b215666b74ab0bd0e41b13038cc9e = {
#     "series": [
#         {
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
# ...

# %%
geo = Geo("全国主要城市空气质量", "data from pm2.5", title_color="#fff", title_pos="center", width=1000, height=600,
background_color='#404a59')
attr, value = geo.cast(data1)
geo.add("", attr, value,
        type="heatmap",
        is_visualmap=True, visual_range=[0, 300], visual_text_color='#fff')
# geo.show_config()
# geo.render(path='全国主要城市空气质量-热力图.html')
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="ce02f328310e4410896f72112b62529f" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_ce02f328310e4410896f72112b62529f = echarts.init(document.getElementById('ce02f328310e4410896f72112b62529f'), 'light', {renderer: 'canvas'});
#
# var option_ce02f328310e4410896f72112b62529f = {
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6d77\u95e8",
#                     "value": [
#                         121.15,
#                         31.89,
#                         9
#                     ]
#                 },
#                 {
# ...

# %%
from pyecharts import Geo

value = [20,30,40,60,70,80,90,100,10]
attr = ['荆州','长沙','渭南','临汾','十堰','唐山','郴州','铜陵','呼和浩特']
geo = Geo("全国各地销售量图",width=1200,height=600)
geo.add("各网点销售量",attr,value,
        type="effectScatter",
        border_color="#ffffff",  # 区域边界色
        symbol="circle",symbol_size=20,symbol_color="#CD4F39",
        is_label_show=True,label_text_color="#00FF00",label_pos="inside",
        geo_normal_color="#548B54",
        geo_emphasis_color="#20B2AA")
# geo.show_config()
# geo.render("全国各地销售量图.html")
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="d88d3aedf86f473f802bf5bdf2a5f33f" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_d88d3aedf86f473f802bf5bdf2a5f33f = echarts.init(document.getElementById('d88d3aedf86f473f802bf5bdf2a5f33f'), 'light', {renderer: 'canvas'});
#
# var option_d88d3aedf86f473f802bf5bdf2a5f33f = {
#     "series": [
#         {
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12,
#                         "color": "#00FF00"
#                     },
#                     "position": "inside",
#                     "show": true
#                 },
#                 "emphasis": {
#                     "textStyle": {
# ...

# %%
from pyecharts import Geo

data =[
    ('朝阳区', 50), ('东城区', 60), ('海淀区', 35),('通州区', 55), ('房山区', 63), ('门头沟区', 45),
    ('昌平区', 44), ('平谷区', 72), ('西城区', 40), ('丰台区', 30), ('石景山区', 35),('大兴区', 70), 
]
geo = Geo("北京城市空气质量", "data from pm2.5", title_color="#fff",
          title_pos="center", width=1000,
          height=600, background_color='#404a59')
attr, value = geo.cast(data)
geo.add("", attr, value, maptype='北京',
        type="effectScatter",
        is_random=True, effect_scale=5,
#         is_legend_show=True
       )
geo
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'beijing': '/nbextensions/echarts-china-cities-js/beijing'
#         }
#     });
# </script>
#     <div id="8f085ab60be7422db91e263e53d55683" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'beijing'], function(echarts) {
#
# var myChart_8f085ab60be7422db91e263e53d55683 = echarts.init(document.getElementById('8f085ab60be7422db91e263e53d55683'), 'light', {renderer: 'canvas'});
#
# var option_8f085ab60be7422db91e263e53d55683 = {
#     "series": [
#         {
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
# ...

# %%
from pyecharts import GeoLines, Style

style = Style(
    title_top="20",
    title_pos="center",
    title_color='#CD5555',
    width=1000,
    height=600,
    background_color="#404a59"
)

data_guangzhou = [
    ["广州", "上海"],
    ["广州", "北京"],
    ["广州", "南京"],
    ["广州", "重庆"],
    ["广州", "兰州"],
    ["广州", "杭州"]
]
geolines = GeoLines("GeoLines 示例", **style.init_style)
geolines.add("从广州出发", data_guangzhou,
             is_legend_show=False
            )
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="0cc1fe4bd2154e0aaa433cdde458c334" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_0cc1fe4bd2154e0aaa433cdde458c334 = echarts.init(document.getElementById('0cc1fe4bd2154e0aaa433cdde458c334'), 'light', {renderer: 'canvas'});
#
# var option_0cc1fe4bd2154e0aaa433cdde458c334 = {
#     "series": [
#         {
#             "type": "lines",
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "effect": {
#                 "period": 6,
#                 "symbol": "circle",
#                 "symbolSize": 5,
#                 "trailLength": 0,
#                 "color": "#fff",
#                 "show": true
#             },
# ...

# %%
data_beijing = [
    ["北京", "上海"],
    ["北京", "沈阳"],
    ["北京", "南京"],
    ["北京", "重庆"],
    ["北京", "兰州"],
    ["北京", "成都"],
    ["北京", "拉萨"],
    ["北京", "杭州"]
]

# %%
from pyecharts import GeoLines, Style

style_geo = style.add(
    is_label_show=True,
    line_curve=0.2,
    line_opacity=0.6,
    legend_text_color="#eee",
    legend_pos="right",
    geo_effect_symbol="plane",
    geo_effect_symbolsize=15,
    label_color=['#a6c84c', '#ffa022', '#46bee9'],
    label_pos="right",
    label_formatter="{b}",
    label_text_color="#eee",
    legend_selectedmode="single", #指定单例模式
)
geolines = GeoLines("GeoLines 示例",**style.init_style)
geolines.add("从广州出发", data_guangzhou, **style_geo)
geolines.add("从北京出发", data_beijing, **style_geo)
geolines
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="f8474001418b420f8dc40b9d1a5cbfb3" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_f8474001418b420f8dc40b9d1a5cbfb3 = echarts.init(document.getElementById('f8474001418b420f8dc40b9d1a5cbfb3'), 'light', {renderer: 'canvas'});
#
# var option_f8474001418b420f8dc40b9d1a5cbfb3 = {
#     "series": [
#         {
#             "type": "lines",
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "effect": {
#                 "period": 6,
# ...
