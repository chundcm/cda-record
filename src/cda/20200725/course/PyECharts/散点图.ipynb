# %% [markdown]
# # Scatter（散点图）

# %% [markdown]
# 直角坐标系上的散点图可以用来展现数据的 x，y 之间的关系，如果数据项有多个维度，可以用颜色来表现，利用 geo 组件。

# %%
from pyecharts import Scatter
import numpy as np

v1 = np.random.randint(1,100,100)
v2 = np.random.randint(1,100,100)
scatter = Scatter("散点图示例")
scatter.add("A", v1, v2)
scatter.add("B", v1[::-1], v2)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="319b2659b8d14e579206b328d274f7cd" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_319b2659b8d14e579206b328d274f7cd = echarts.init(document.getElementById('319b2659b8d14e579206b328d274f7cd'), 'light', {renderer: 'canvas'});
#
# var option_319b2659b8d14e579206b328d274f7cd = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "circle",
#             "data": [
#                 [
#                     79.0,
#                     19.0
#                 ],
#                 [
#                     75.0,
#                     8.0
#                 ],
#                 [
#                     94.0,
#                     64.0
#                 ],
#                 [
#                     95.0,
#                     37.0
#                 ],
#                 [
#                     52.0,
#                     23.0
#                 ],
#                 [
#                     84.0,
#                     10.0
#                 ],
#                 [
#                     85.0,
#                     71.0
#                 ],
#                 [
#                     23.0,
#                     58.0
#                 ],
#                 [
#                     47.0,
#                     45.0
#                 ],
#                 [
#                     9.0,
#                     43.0
#                 ],
#                 [
#                     26.0,
#                     59.0
#                 ],
#                 [
#                     64.0,
#                     52.0
#                 ],
#                 [
#                     89.0,
#                     66.0
#                 ],
#                 [
#                     75.0,
#                     62.0
#                 ],
#                 [
#                     15.0,
#                     60.0
#                 ],
#                 [
#                     92.0,
#                     45.0
#                 ],
#                 [
#                     67.0,
#                     64.0
#                 ],
#                 [
#                     12.0,
#                     83.0
#                 ],
#                 [
#                     30.0,
#                     5.0
#                 ],
#                 [
#                     60.0,
#                     45.0
#                 ],
#                 [
#                     98.0,
#                     42.0
#                 ],
#                 [
#                     23.0,
#                     37.0
#                 ],
#                 [
#                     74.0,
#                     69.0
#                 ],
#                 [
#                     37.0,
#                     54.0
#                 ],
#                 [
#                     16.0,
#                     27.0
#                 ],
#                 [
#                     37.0,
#                     51.0
#                 ],
#                 [
#                     60.0,
#                     55.0
#                 ],
#                 [
#                     69.0,
#                     32.0
#                 ],
#                 [
#                     64.0,
#                     23.0
#                 ],
#                 [
#                     79.0,
#                     57.0
#                 ],
#                 [
#                     92.0,
#                     85.0
#                 ],
#                 [
#                     2.0,
#                     28.0
#                 ],
#                 [
#                     80.0,
#                     2.0
#                 ],
#                 [
#                     93.0,
#                     41.0
#                 ],
#                 [
#                     81.0,
#                     50.0
#                 ],
#                 [
#                     42.0,
#                     29.0
#                 ],
#                 [
#                     17.0,
#                     17.0
#                 ],
#                 [
#                     53.0,
#                     47.0
#                 ],
#                 [
#                     3.0,
#                     71.0
#                 ],
#                 [
#                     54.0,
#                     54.0
#                 ],
#                 [
#                     94.0,
#                     45.0
#                 ],
#                 [
#                     98.0,
#                     77.0
#                 ],
#                 [
#                     17.0,
#                     99.0
#                 ],
#                 [
#                     3.0,
#                     6.0
#                 ],
#                 [
#                     9.0,
#                     56.0
#                 ],
#                 [
#                     13.0,
#                     42.0
#                 ],
#                 [
#                     16.0,
#                     68.0
#                 ],
#                 [
#                     98.0,
#                     33.0
#                 ],
#                 [
#                     93.0,
#                     82.0
#                 ],
#                 [
#                     98.0,
#                     16.0
#                 ],
#                 [
#                     6.0,
#                     10.0
#                 ],
#                 [
#                     90.0,
#                     38.0
#                 ],
#                 [
#                     22.0,
#                     76.0
#                 ],
#                 [
#                     92.0,
#                     50.0
#                 ],
#                 [
#                     25.0,
#                     45.0
#                 ],
#                 [
#                     27.0,
#                     19.0
#                 ],
#                 [
#                     8.0,
#                     77.0
#                 ],
#                 [
#                     90.0,
#                     23.0
#                 ],
#                 [
#                     30.0,
#                     18.0
#                 ],
#                 [
#                     67.0,
#                     12.0
#                 ],
#                 [
#                     1.0,
#                     80.0
#                 ],
#                 [
#                     87.0,
#                     93.0
#                 ],
#                 [
#                     87.0,
#                     50.0
#                 ],
#                 [
#                     9.0,
#                     46.0
#                 ],
#                 [
#                     21.0,
#                     6.0
#                 ],
#                 [
#                     36.0,
#                     99.0
#                 ],
#                 [
#                     86.0,
#                     4.0
#                 ],
#                 [
#                     47.0,
#                     66.0
#                 ],
#                 [
#                     47.0,
#                     79.0
#                 ],
#                 [
#                     23.0,
#                     37.0
#                 ],
#                 [
#                     92.0,
#                     50.0
#                 ],
#                 [
#                     40.0,
#                     12.0
#                 ],
#                 [
#                     96.0,
#                     18.0
#                 ],
#                 [
#                     71.0,
#                     81.0
#                 ],
#                 [
#                     15.0,
#                     71.0
#                 ],
#                 [
#                     9.0,
#                     3.0
#                 ],
#                 [
#                     9.0,
#                     19.0
#                 ],
#                 [
#                     50.0,
#                     67.0
#                 ],
#                 [

# %% [markdown]
# 散点图表示因变量随自变量而变化的大致趋势，据此可以选择合适的函数对数据点进行拟合。顾名思义，就是散落的点去表达信息。
# 主要用于查找变量之间的相关性。

# %%
from pyecharts import Scatter

area = [30,40,50,60,70,80,90,100,120,150,200,300,400]
price = [1645,2745,3845,4945,5145,6450,7450,8450,9450,10450,13450,18000,24450]

scatter = Scatter("房价和房屋面积的关系")
scatter.add("", area, price, xaxis_name='面积', yaxis_name='房价',
            yaxis_name_pos='middle',
            yaxis_name_gap=60
           )
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b1ebadea892a46cdb4d4b0bbdceccd93" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b1ebadea892a46cdb4d4b0bbdceccd93 = echarts.init(document.getElementById('b1ebadea892a46cdb4d4b0bbdceccd93'), 'light', {renderer: 'canvas'});
#
# var option_b1ebadea892a46cdb4d4b0bbdceccd93 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "circle",
#             "data": [
#                 [
#                     30,
#                     1645
#                 ],
#                 [
#                     40,
#                     2745
#                 ],
#                 [
#                     50,
#                     3845
#                 ],
#                 [
#                     60,
#                     4945
#                 ],
#                 [
#                     70,
#                     5145
#                 ],
#                 [
#                     80,
#                     6450
#                 ],
#                 [
#                     90,
#                     7450
#                 ],
#                 [
#                     100,
#                     8450
#                 ],
#                 [
#                     120,
#                     9450
#                 ],
#                 [
#                     150,
#                     10450
#                 ],
#                 [
#                     200,
#                     13450
#                 ],
#                 [
#                     300,
#                     18000
#                 ],
#                 [
#                     400,
#                     24450
#                 ]
#             ],
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 14517,
#             "markPoint": {
#                 "data": []
#             },
#             "symbolSize": 10,
#             "type": "scatter"
#         }
#     ],
#     "series_id": 14517,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "text": "\u623f\u4ef7\u548c\u623f\u5c4b\u9762\u79ef\u7684\u5173\u7cfb",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "orient": "horizontal",
#             "data": [
#                 ""
#             ],
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 60,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "inverse": false,
#             "name": "\u623f\u4ef7",
#             "show": true,
#             "type": "value",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle"
#         }
#     ],
#     "xAxis": [
#         {
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "name": "\u9762\u79ef",
#             "type": "value",
#             "boundaryGap": true,
#             "data": [
#                 30,
#                 40,
#                 50,
#                 60,
#                 70,
#                 80,
#                 90,
#                 100,
#                 120,
#                 150,
#                 200,
#                 300,
#                 400
#             ],
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "nameGap": 25,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     }
# };
# myChart_b1ebadea892a46cdb4d4b0bbdceccd93.setOption(option_b1ebadea892a46cdb4d4b0bbdceccd93);
#
#     });
# </script>

# %% [markdown]
# 利用 Visualmap 组件，通过颜色映射数值大小。

# %%
scatter = Scatter("散点图示例")
scatter.add("A", v1, v2)
scatter.add("B", v1[::-1], v2,
           is_visualmap=True)
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f9494d0fb59e411cac9b3658f515411f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f9494d0fb59e411cac9b3658f515411f = echarts.init(document.getElementById('f9494d0fb59e411cac9b3658f515411f'), 'light', {renderer: 'canvas'});
#
# var option_f9494d0fb59e411cac9b3658f515411f = {
#     "visualMap": {
#         "left": "left",
#         "splitNumber": 5,
#         "text": [
#             "high",
#             "low"
#         ],
#         "top": "bottom",
#         "showLabel": true,
#         "type": "continuous",
#         "orient": "vertical",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "textStyle": {}
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "circle",
#             "data": [
#                 [
#                     79.0,
#                     19.0
#                 ],
#                 [
#                     75.0,
#                     8.0
#                 ],
#                 [
#                     94.0,
#                     64.0
#                 ],
#                 [
#                     95.0,
#                     37.0
#                 ],
#                 [
#                     52.0,
#                     23.0
#                 ],
#                 [
#                     84.0,
#                     10.0
#                 ],
#                 [
#                     85.0,
#                     71.0
#                 ],
#                 [
#                     23.0,
#                     58.0
#                 ],
#                 [
#                     47.0,
#                     45.0
#                 ],
#                 [
#                     9.0,
#                     43.0
#                 ],
#                 [
#                     26.0,
#                     59.0
#                 ],
#                 [
#                     64.0,
#                     52.0
#                 ],
#                 [
#                     89.0,
#                     66.0
#                 ],
#                 [
#                     75.0,
#                     62.0
#                 ],
#                 [
#                     15.0,
#                     60.0
#                 ],
#                 [
#                     92.0,
#                     45.0
#                 ],
#                 [
#                     67.0,
#                     64.0
#                 ],
#                 [
#                     12.0,
#                     83.0
#                 ],
#                 [
#                     30.0,
#                     5.0
#                 ],
#                 [
#                     60.0,
#                     45.0
#                 ],
#                 [
#                     98.0,
#                     42.0
#                 ],
#                 [
#                     23.0,
#                     37.0
#                 ],
#                 [
#                     74.0,
#                     69.0
#                 ],
#                 [
#                     37.0,
#                     54.0
#                 ],
#                 [
#                     16.0,
#                     27.0
#                 ],
#                 [
#                     37.0,
#                     51.0
#                 ],
#                 [
#                     60.0,
#                     55.0
#                 ],
#                 [
#                     69.0,
#                     32.0
#                 ],
#                 [
#                     64.0,
#                     23.0
#                 ],
#                 [
#                     79.0,
#                     57.0
#                 ],
#                 [
#                     92.0,
#                     85.0
#                 ],
#                 [
#                     2.0,
#                     28.0
#                 ],
#                 [
#                     80.0,
#                     2.0
#                 ],
#                 [
#                     93.0,
#                     41.0
#                 ],
#                 [
#                     81.0,
#                     50.0
#                 ],
#                 [
#                     42.0,
#                     29.0
#                 ],
#                 [
#                     17.0,
#                     17.0
#                 ],
#                 [
#                     53.0,
#                     47.0
#                 ],
#                 [
#                     3.0,
#                     71.0
#                 ],
#                 [
#                     54.0,
#                     54.0
#                 ],
#                 [
#                     94.0,
#                     45.0
#                 ],
#                 [
#                     98.0,
#                     77.0
#                 ],
#                 [
#                     17.0,
#                     99.0
#                 ],
#                 [
#                     3.0,
#                     6.0
#                 ],
#                 [
#                     9.0,
#                     56.0
#                 ],
#                 [
#                     13.0,
#                     42.0
#                 ],
#                 [
#                     16.0,
#                     68.0
#                 ],
#                 [
#                     98.0,
#                     33.0
#                 ],
#                 [
#                     93.0,
#                     82.0
#                 ],
#                 [
#                     98.0,
#                     16.0
#                 ],
#                 [
#                     6.0,
#                     10.0
#                 ],
#                 [
#                     90.0,
#                     38.0
#                 ],
#                 [
#                     22.0,
#                     76.0
#                 ],
#                 [
#                     92.0,
#                     50.0
#                 ],
#                 [
#                     25.0,
#                     45.0
#                 ],
#                 [
#                     27.0,
#                     19.0
#                 ],
#                 [
#                     8.0,
#                     77.0
#                 ],
#                 [
#                     90.0,
#                     23.0
#                 ],
#                 [
#                     30.0,
#                     18.0
#                 ],
#                 [
#                     67.0,
#                     12.0
#                 ],
#                 [
#                     1.0,
#                     80.0
#                 ],
#                 [
#                     87.0,
#                     93.0
#                 ],
#                 [
#                     87.0,
#                     50.0
#                 ],
#                 [
#                     9.0,
#                     46.0
#                 ],
#                 [
#                     21.0,
#                     6.0
#                 ],
#                 [
#                     36.0,
#                     99.0
#                 ],
#                 [
#                     86.0,
#                     4.0
#                 ],
#                 [
#                     47.0,
#                     66.0
#                 ],
#                 [
#                     47.0,
#                     79.0
#                 ],
#                 [
#                     23.0,
#                     37.0
#                 ],
#                 [
#                     92.0,
#                     50.0
#                 ],
#                 [
#                     40.0,
#                     12.0
#                 ],
#                 [
#                     96.0,

# %% [markdown]
# ### 气泡图
# 气泡图是散点图的一种变体，通过每个点的面积大小，反映第三维。

# %% [markdown]
# 利用 Visualmap 组件，通过图形点大小映射数值。

# %%
scatter = Scatter("散点图示例")
scatter.add("气泡图", v1[::-1], v2, is_visualmap=True,
            visual_type='size', visual_range_size=[15, 45])
scatter
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3c5949809f444b37b1411883bc47226e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3c5949809f444b37b1411883bc47226e = echarts.init(document.getElementById('3c5949809f444b37b1411883bc47226e'), 'light', {renderer: 'canvas'});
#
# var option_3c5949809f444b37b1411883bc47226e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "left": "left",
#         "splitNumber": 5,
#         "text": [
#             "high",
#             "low"
#         ],
#         "top": "bottom",
#         "showLabel": true,
#         "type": "continuous",
#         "orient": "vertical",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "symbolSize": [
#                 15,
#                 45
#             ]
#         },
#         "calculable": true,
#         "textStyle": {}
#     },
#     "series": [
#         {
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "circle",
#             "data": [
#                 [
#                     61.0,
#                     19.0
#                 ],
#                 [
#                     16.0,
#                     8.0
#                 ],
#                 [
#                     8.0,
#                     64.0
#                 ],
#                 [
#                     25.0,
#                     37.0
#                 ],
#                 [
#                     27.0,
#                     23.0
#                 ],
#                 [
#                     70.0,
#                     10.0
#                 ],
#                 [
#                     31.0,
#                     71.0
#                 ],
#                 [
#                     58.0,
#                     58.0
#                 ],
#                 [
#                     95.0,
#                     45.0
#                 ],
#                 [
#                     66.0,
#                     43.0
#                 ],
#                 [
#                     74.0,
#                     59.0
#                 ],
#                 [
#                     74.0,
#                     52.0
#                 ],
#                 [
#                     60.0,
#                     66.0
#                 ],
#                 [
#                     88.0,
#                     62.0
#                 ],
#                 [
#                     81.0,
#                     60.0
#                 ],
#                 [
#                     39.0,
#                     45.0
#                 ],
#                 [
#                     45.0,
#                     64.0
#                 ],
#                 [
#                     28.0,
#                     83.0
#                 ],
#                 [
#                     35.0,
#                     5.0
#                 ],
#                 [
#                     45.0,
#                     45.0
#                 ],
#                 [
#                     87.0,
#                     42.0
#                 ],
#                 [
#                     50.0,
#                     37.0
#                 ],
#                 [
#                     50.0,
#                     69.0
#                 ],
#                 [
#                     9.0,
#                     54.0
#                 ],
#                 [
#                     9.0,
#                     27.0
#                 ],
#                 [
#                     15.0,
#                     51.0
#                 ],
#                 [
#                     71.0,
#                     55.0
#                 ],
#                 [
#                     96.0,
#                     32.0
#                 ],
#                 [
#                     40.0,
#                     23.0
#                 ],
#                 [
#                     92.0,
#                     57.0
#                 ],
#                 [
#                     23.0,
#                     85.0
#                 ],
#                 [
#                     47.0,
#                     28.0
#                 ],
#                 [
#                     47.0,
#                     2.0
#                 ],
#                 [
#                     86.0,
#                     41.0
#                 ],
#                 [
#                     36.0,
#                     50.0
#                 ],
#                 [
#                     21.0,
#                     29.0
#                 ],
#                 [
#                     9.0,
#                     17.0
#                 ],
#                 [
#                     87.0,
#                     47.0
#                 ],
#                 [
#                     87.0,
#                     71.0
#                 ],
#                 [
#                     1.0,
#                     54.0
#                 ],
#                 [
#                     67.0,
#                     45.0
#                 ],
#                 [
#                     30.0,
#                     77.0
#                 ],
#                 [
#                     90.0,
#                     99.0
#                 ],
#                 [
#                     8.0,
#                     6.0
#                 ],
#                 [
#                     27.0,
#                     56.0
#                 ],
#                 [
#                     25.0,
#                     42.0
#                 ],
#                 [
#                     92.0,
#                     68.0
#                 ],
#                 [
#                     22.0,
#                     33.0
#                 ],
#                 [
#                     90.0,
#                     82.0
#                 ],
#                 [
#                     6.0,
#                     16.0
#                 ],
#                 [
#                     98.0,
#                     10.0
#                 ],
#                 [
#                     93.0,
#                     38.0
#                 ],
#                 [
#                     98.0,
#                     76.0
#                 ],
#                 [
#                     16.0,
#                     50.0
#                 ],
#                 [
#                     13.0,
#                     45.0
#                 ],
#                 [
#                     9.0,
#                     19.0
#                 ],
#                 [
#                     3.0,
#                     77.0
#                 ],
#                 [
#                     17.0,
#                     23.0
#                 ],
#                 [
#                     98.0,
#                     18.0
#                 ],
#                 [
#                     94.0,
#                     12.0
#                 ],
#                 [
#                     54.0,
#                     80.0
#                 ],
#                 [
#                     3.0,
#                     93.0
#                 ],
#                 [
#                     53.0,
#                     50.0
#                 ],
#                 [
#                     17.0,
#                     46.0
#                 ],
#                 [
#                     42.0,
#                     6.0
#                 ],
#                 [
#                     81.0,
#                     99.0
#                 ],
#                 [
#                     93.0,
#                     4.0
#                 ],
#                 [
#                     80.0,
#                     66.0
#                 ],
#                 [
#                     2.0,
#                     79.0
#                 ],
#                 [
#                     92.0,
#                     37.0
#                 ],
#                 [
#                     79.0,
#                     50.0
#                 ],
#                 [
#                     64.0,
#                     12.0
#                 ],
#                 [
#                     69.0,
#                     18.0
#                 ],

# %% [markdown]
# ### EffectScatter（带有涟漪特效动画的散点图）
# 利用动画特效可以将某些想要突出的数据进行视觉突出。

# %%
from pyecharts import EffectScatter

v1 = [10, 20, 30, 40, 50, 60]
v2 = [25, 40, 15, 10, 60, 33]
es = EffectScatter("动态散点图示例")
es.add("effectScatter", v1, v2)
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a39bd382cee6424bb77d795726c1aee4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a39bd382cee6424bb77d795726c1aee4 = echarts.init(document.getElementById('a39bd382cee6424bb77d795726c1aee4'), 'light', {renderer: 'canvas'});
#
# var option_a39bd382cee6424bb77d795726c1aee4 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "symbol": "circle",
#             "data": [
#                 [
#                     10,
#                     25
#                 ],
#                 [
#                     20,
#                     40
#                 ],
#                 [
#                     30,
#                     15
#                 ],
#                 [
#                     40,
#                     10
#                 ],
#                 [
#                     50,
#                     60
#                 ],
#                 [
#                     60,
#                     33
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 6080254,
#             "showEffectOn": "render",
#             "name": "effectScatter",
#             "symbolSize": 10,
#             "rippleEffect": {
#                 "period": 4,
#                 "brushType": "stroke",
#                 "scale": 2.5
#             }
#         }
#     ],
#     "series_id": 6080254,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "orient": "horizontal",
#             "data": [
#                 "effectScatter"
#             ],
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "inverse": false,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "type": "value",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle"
#         }
#     ],
#     "xAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "inverse": false,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "type": "value",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "left": "95%",
#         "show": true,
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     }
# };
# myChart_a39bd382cee6424bb77d795726c1aee4.setOption(option_a39bd382cee6424bb77d795726c1aee4);
#
#     });
# </script>

# %%
es = EffectScatter("动态散点图各种图形示例")
es.add("", [10], [10], symbol_size=20, effect_scale=3.5, effect_brushtype = 'fill', effect_period=3, symbol="pin")
es.add("", [20], [20], symbol_size=12, effect_scale=4.5, effect_period=4,symbol="rect")
es.add("", [30], [30], symbol_size=30, effect_scale=5.5, effect_period=5,symbol="roundRect")
es.add("", [40], [40], symbol_size=10, effect_scale=6.5, effect_brushtype='fill',symbol="diamond")
es.add("", [50], [50], symbol_size=16, effect_scale=5.5, effect_period=3,symbol="arrow")
es.add("", [60], [60], symbol_size=6,  effect_scale=2.5,  effect_period=3,symbol="triangle")
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="37c2138e534941d993c133be7070e7f3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_37c2138e534941d993c133be7070e7f3 = echarts.init(document.getElementById('37c2138e534941d993c133be7070e7f3'), 'light', {renderer: 'canvas'});
#
# var option_37c2138e534941d993c133be7070e7f3 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "series": [
#         {
#             "symbol": "pin",
#             "data": [
#                 [
#                     10,
#                     10
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3210184,
#             "showEffectOn": "render",
#             "symbolSize": 20,
#             "rippleEffect": {
#                 "period": 3,
#                 "brushType": "fill",
#                 "scale": 3.5
#             }
#         },
#         {
#             "symbol": "rect",
#             "data": [
#                 [
#                     20,
#                     20
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3210184,
#             "showEffectOn": "render",
#             "symbolSize": 12,
#             "rippleEffect": {
#                 "period": 4,
#                 "brushType": "stroke",
#                 "scale": 4.5
#             }
#         },
#         {
#             "symbol": "roundRect",
#             "data": [
#                 [
#                     30,
#                     30
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3210184,
#             "showEffectOn": "render",
#             "symbolSize": 30,
#             "rippleEffect": {
#                 "period": 5,
#                 "brushType": "stroke",
#                 "scale": 5.5
#             }
#         },
#         {
#             "symbol": "diamond",
#             "data": [
#                 [
#                     40,
#                     40
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3210184,
#             "showEffectOn": "render",
#             "symbolSize": 10,
#             "rippleEffect": {
#                 "period": 4,
#                 "brushType": "fill",
#                 "scale": 6.5
#             }
#         },
#         {
#             "symbol": "arrow",
#             "data": [
#                 [
#                     50,
#                     50
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3210184,
#             "showEffectOn": "render",
#             "symbolSize": 16,
#             "rippleEffect": {
#                 "period": 3,
#                 "brushType": "stroke",
#                 "scale": 5.5
#             }
#         },
#         {
#             "symbol": "triangle",
#             "data": [
#                 [
#                     60,
#                     60
#                 ]
#             ],
#             "type": "effectScatter",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 3210184,
#             "showEffectOn": "render",
#             "symbolSize": 6,
#             "rippleEffect": {
#                 "period": 3,
#                 "brushType": "stroke",
#                 "scale": 2.5
#             }
#         }
#     ],
#     "series_id": 3210184,
#     "tooltip": {
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "left": "center",
#             "orient": "horizontal",
#             "data": [
#                 "",
#                 "",
#                 "",
#                 "",
#                 "",
#                 ""
#             ],
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "text": "\u52a8\u6001\u6563\u70b9\u56fe\u5404\u79cd\u56fe\u5f62\u793a\u4f8b",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "nameGap": 25,
#             "boundaryGap": true,
#             "splitLine": {
#                 "show": true
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "inverse": false,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "type": "val
