# %% [markdown]
# # Gague（仪表盘）

# %% [markdown]
# 仪表盘（guage，speedometer，dial chart，dashboard），是模仿汽车速度表的一种图表，常用来反映预算完成率、收入增长率等比率性指标。它简单、直观，人人会看，是商业面板（Dashboard）最主要特征的图表类型。

# %%
from pyecharts import Gauge

gauge = Gauge("仪表盘示例")
gauge.add("EM营销情况", "邮件打开率", 73)
gauge
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9d1b003089af43d9b4700a66399f9cb6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9d1b003089af43d9b4700a66399f9cb6 = echarts.init(document.getElementById('9d1b003089af43d9b4700a66399f9cb6'), 'light', {renderer: 'canvas'});
#
# var option_9d1b003089af43d9b4700a66399f9cb6 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{a} <br/>{b} : {c}%",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
#             "top": "top",
# ...

# %% [markdown]
# 语法及参数：
# * add(name, attr, value, scale_range=None, angle_range=None, **kwargs)
#     * name -> str 图例名称
#     * attr -> list 属性名称
#     * value -> list 属性所对应的值
#     * scale_range -> list 仪表盘数据范围。默认为 [0, 100]
#     * angle_range -> list 仪表盘角度范围。默认为 [225, -45]

# %%
gauge = Gauge("仪表盘示例")
gauge.add("OBTM触及率", "OBTM触及率", 96.66, scale_range=[0, 180], angle_range=[270, 0], is_legend_show=True)
gauge
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3fdc774e1585470d8226e8db6e663182" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3fdc774e1585470d8226e8db6e663182 = echarts.init(document.getElementById('3fdc774e1585470d8226e8db6e663182'), 'light', {renderer: 'canvas'});
#
# var option_3fdc774e1585470d8226e8db6e663182 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": "{a} <br/>{b} : {c}%",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
#             "top": "top",
# ...

# %% [markdown]
# # Liquyid（水球图）

# %% [markdown]
# 主要用来突出数据的百分比。

# %%
from pyecharts import Liquid

liquid = Liquid("水球图示例")
liquid.add("Liquid", [0.6])
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="1aed3a5bd2fb4703a6f5ddc37d558b97" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_1aed3a5bd2fb4703a6f5ddc37d558b97 = echarts.init(document.getElementById('1aed3a5bd2fb4703a6f5ddc37d558b97'), 'light', {renderer: 'canvas'});
#
# var option_1aed3a5bd2fb4703a6f5ddc37d558b97 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...

# %% [markdown]
# 语法及参数：
# * add(name, data, shape='circle', liquid_color=None, is_liquid_animation=True, is_liquid_outline_show=True, **kwargs)
#     * name -> str 图例名称
#     * data -> list 数据项
#     * shape -> str 水球外形，有'circle', 'rect', 'roundRect', 'triangle', 'diamond', 'pin', 'arrow'可选。默认'circle'。也可以为自定义的 SVG 路径。
#     * liquid_color -> list 波浪颜色，默认的颜色列表为['#294D99', '#156ACF', '#1598ED', '#45BDFF']。
#     * is_liquid_animation -> bool 是否显示波浪动画，默认为 True。
#     * is_liquid_outline_show -> bool 是否显示边框，默认为 True。

# %%
from pyecharts import Liquid

liquid = Liquid("水球图示例")
liquid.add("Liquid", [0.6, 0.5, 0.4], is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="5a0f28d687d641e39af7b5cb724351d3" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_5a0f28d687d641e39af7b5cb724351d3 = echarts.init(document.getElementById('5a0f28d687d641e39af7b5cb724351d3'), 'light', {renderer: 'canvas'});
#
# var option_5a0f28d687d641e39af7b5cb724351d3 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...

# %%
from pyecharts import Liquid

liquid = Liquid("水球图示例")
liquid.add("Liquid", [0.6, 0.5, 0.4, 0.3],
           is_liquid_animation=False, shape='diamond')
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="dce9344e58d246fc8cd128f0780a1a08" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_dce9344e58d246fc8cd128f0780a1a08 = echarts.init(document.getElementById('dce9344e58d246fc8cd128f0780a1a08'), 'light', {renderer: 'canvas'});
#
# var option_dce9344e58d246fc8cd128f0780a1a08 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...

# %%
from pyecharts import Liquid

shape = ("path://M367.855,428.202c-3.674-1.385-7.452-1.966-11.146-1"
         ".794c0.659-2.922,0.844-5.85,0.58-8.719 c-0.937-10.407-7."
         "663-19.864-18.063-23.834c-10.697-4.043-22.298-1.168-29.9"
         "02,6.403c3.015,0.026,6.074,0.594,9.035,1.728 c13.626,5."
         "151,20.465,20.379,15.32,34.004c-1.905,5.02-5.177,9.115-9"
         ".22,12.05c-6.951,4.992-16.19,6.536-24.777,3.271 c-13.625"
         "-5.137-20.471-20.371-15.32-34.004c0.673-1.768,1.523-3.423"
         ",2.526-4.992h-0.014c0,0,0,0,0,0.014 c4.386-6.853,8.145-14"
         ".279,11.146-22.187c23.294-61.505-7.689-130.278-69.215-153"
         ".579c-61.532-23.293-130.279,7.69-153.579,69.202 c-6.371,"
         "16.785-8.679,34.097-7.426,50.901c0.026,0.554,0.079,1.121,"
         "0.132,1.688c4.973,57.107,41.767,109.148,98.945,130.793 c58."
         "162,22.008,121.303,6.529,162.839-34.465c7.103-6.893,17.826"
         "-9.444,27.679-5.719c11.858,4.491,18.565,16.6,16.719,28.643 "
         "c4.438-3.126,8.033-7.564,10.117-13.045C389.751,449.992,"
         "382.411,433.709,367.855,428.202z")
liquid = Liquid("水球图示例", width=1000, height=600)
liquid.add("Liquid", [0.6, 0.5, 0.4, 0.3],
           shape=shape, is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="68dabf5b08114c06a44dc5e58a909c4b" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_68dabf5b08114c06a44dc5e58a909c4b = echarts.init(document.getElementById('68dabf5b08114c06a44dc5e58a909c4b'), 'light', {renderer: 'canvas'});
#
# var option_68dabf5b08114c06a44dc5e58a909c4b = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
        )
liquid = Liquid("水球图示例", width=500, height=360)
liquid.add("Liquid", [0.75, 0.5, 0.4],
           shape=shape, is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="9e616d4904fb45b3af114f0e8b9a7e6b" style="width:500px;height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_9e616d4904fb45b3af114f0e8b9a7e6b = echarts.init(document.getElementById('9e616d4904fb45b3af114f0e8b9a7e6b'), 'light', {renderer: 'canvas'});
#
# var option_9e616d4904fb45b3af114f0e8b9a7e6b = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...

# %%
from pyecharts import Liquid

shape = ("path://M12 0C5.372 0 0 5.372 0 12s5.372 12 12 12 12-5.372 12-12S18.628 0 12 0zm1.604 14.4h-3.405V18H7.801V6h5.804c2.319 0 4.2 1.88 4.2 4.199 0 2.321-1.881 4.201-4.201 4.201z")
liquid = Liquid("水球图示例", width=500, height=360)
liquid.add("Liquid", [0.6, 0.5, 0.4, 0.3],
           shape=shape, is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="5c708ff651834b139fc6efed4ea810a6" style="width:500px;height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_5c708ff651834b139fc6efed4ea810a6 = echarts.init(document.getElementById('5c708ff651834b139fc6efed4ea810a6'), 'light', {renderer: 'canvas'});
#
# var option_5c708ff651834b139fc6efed4ea810a6 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...

# %%
from pyecharts import Liquid

shape = ('path://M-244.396,44.399c0,0,0.47-2.931-2.427-6.512c2.819-8.221,3.21-15.709,3.21-15.709s5.795,1.383,5.795,7.325C-237.818,39.679-244.396,44.399-244.396,44.399z M-260.371,40.827c0,0-3.881-12.946-3.881-18.319c0-2.416,0.262-4.566,0.669-6.517h17.684c0.411,1.952,0.675,4.104,0.675,6.519c0,5.291-3.87,18.317-3.87,18.317H-260.371z M-254.745,18.951c-1.99,0-3.603,1.676-3.603,3.744c0,2.068,1.612,3.744,3.603,3.744c1.988,0,3.602-1.676,3.602-3.744S-252.757,18.951-254.745,18.951z M-255.521,2.228v-5.098h1.402v4.969c1.603,1.213,5.941,5.069,7.901,12.5h-17.05C-261.373,7.373-257.245,3.558-255.521,2.228zM-265.07,44.399c0,0-6.577-4.721-6.577-14.896c0-5.942,5.794-7.325,5.794-7.325s0.393,7.488,3.211,15.708C-265.539,41.469-265.07,44.399-265.07,44.399z M-252.36,45.15l-1.176-1.22L-254.789,48l-1.487-4.069l-1.019,2.116l-1.488-3.826h8.067L-252.36,45.15z')
liquid = Liquid("水球图示例", width=500, height=360)
liquid.add("Liquid", [0.5, 0.4, 0.3],
           shape=shape, is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="4ee8696fbcf249c08798fc7a57190f1d" style="width:500px;height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_4ee8696fbcf249c08798fc7a57190f1d = echarts.init(document.getElementById('4ee8696fbcf249c08798fc7a57190f1d'), 'light', {renderer: 'canvas'});
#
# var option_4ee8696fbcf249c08798fc7a57190f1d = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...

# %%
from pyecharts import Liquid

shape = ('path://M29.902,23.275c1.86,0,3.368-1.506,3.368-3.365c0-1.859-1.508-3.365-3.368-3.365 c-1.857,0-3.365,1.506-3.365,3.365C26.537,21.769,28.045,23.275,29.902,23.275z M36.867,30.74c-1.666-0.467-3.799-1.6-4.732-4.199 c-0.932-2.6-3.131-2.998-4.797-2.998s-7.098,3.894-7.098,3.894c-1.133,1.001-2.1,6.502-0.967,6.769 c1.133,0.269,1.266-1.533,1.934-3.599c0.666-2.065,3.797-3.466,3.797-3.466s0.201,2.467-0.398,3.866 c-0.599,1.399-1.133,2.866-1.467,6.198s-1.6,3.665-3.799,6.266c-2.199,2.598-0.6,3.797,0.398,3.664 c1.002-0.133,5.865-5.598,6.398-6.998c0.533-1.397,0.668-3.732,0.668-3.732s0,0,2.199,1.867c2.199,1.865,2.332,4.6,2.998,7.73 s2.332,0.934,2.332-0.467c0-1.401,0.269-5.465-1-7.064c-1.265-1.6-3.73-3.465-3.73-5.265s1.199-3.732,1.199-3.732 c0.332,1.667,3.335,3.065,5.599,3.399C38.668,33.206,38.533,31.207,36.867,30.74z')
liquid = Liquid("水球图示例", width=500, height=360)
liquid.add("Liquid", [0.5, 0.4, 0.3],
           liquid_color=['#FFDEAD','#150ACF','#1590ED','#40BDFF'],
           shape=shape, is_liquid_outline_show=False)
liquid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'liquidfill': '/nbextensions/echarts/echarts-liquidfill.min'
#         }
#     });
# </script>
#     <div id="72c8f107b3fa43829d74290bc7668dd6" style="width:500px;height:360px;"></div>
#
#
# <script>
#     require(['echarts', 'liquidfill'], function(echarts) {
#
# var myChart_72c8f107b3fa43829d74290bc7668dd6 = echarts.init(document.getElementById('72c8f107b3fa43829d74290bc7668dd6'), 'light', {renderer: 'canvas'});
#
# var option_72c8f107b3fa43829d74290bc7668dd6 = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333"
#     },
#     "legend": [
#         {
#             "show": true,
# ...
