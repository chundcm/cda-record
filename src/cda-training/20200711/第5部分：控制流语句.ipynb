# %% [markdown]
# ```
# ```
# # 第5部分：控制流语句

# %% [markdown]
# - Created By：菊安酱
# - Date：2020.07.11

# %% [markdown]
# 在 Python 中，有三种控制流类型：
# • 顺序结构
# • 分支结构
# • 循环结构
# 复杂的控制流语句都是由这三个基本的控制流组成的。

# %% [markdown]
# <img src='https://pictes.oss-cn-beijing.aliyuncs.com/%E8%8F%8A%E5%AE%89%E9%85%B1/Python%E5%9F%BA%E7%A1%80/%E6%8E%A7%E5%88%B6%E6%B5%81.png' width=700>

# %% [markdown]
# ## 1. 顺序结构
# 顺序结构是最普通的结构，就是普通的至上而下逐行运行的代码结构。

# %%
a = '顺序结构'
print(a)

b = '自上而下'
print(b)

c = '逐条运行'
print(c)

# %% [markdown]
# 在顺序结构当中，如果代码在某行出错则后面的代码都不会被执行：

# %%
a = 111
print(a)
raise NameError # 这里我们故意创建并抛出一个错误
b = 222 # 下面的这两条代码都不会执行
print(b)

# %% [markdown]
# ## 2. 分支结构

# %% [markdown]
# Python 条件语句是通过一条或多条语句的执行结果（True 或者 False）来决定执行的代码块。

# %% [markdown]
# ```python
# if <条件判断 1>:
#     <执行语句块 1>
# elif <条件判断 2>:
#     <执行语句块 2>
# elif <条件判断 3>:
#     <执行语句块 3>
# # ... 多个 elif...
# else:
#     <执行语句块 4>
#     ```

# %% [markdown]
# 可能会有零到多个 elif 部分，else 是可选的。关键字"elif" 是"else if" 的缩写。

# %% [markdown]
# ### 2.1 if 语句独立使用

# %% [markdown]
# ```python
# if <条件判断 1>:        #条件为真（True）执行操作
#     <执行语句块 1>
# ```

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
age = 20

if age >= 18:
    print('your age is', age)
    print('adult')

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %% [markdown]
# ```
#
#
# ```
# ### 2.2  if- else语句

# %% [markdown]
# ```
# if <条件判断 1>:
#     <执行语句块 1>    #条件为真（True）执行操作
# else:
#     <执行语句块 4>    #条件为假（False）执行操作
#
#
# ```

# %% [markdown]
# ![_auto_2](attachment:_auto_2)

# %%
age = 17

if age >= 18:
    print('your age is', age)
    print('adult')
else:
    print('your age is', age)
    print('teenager')

# %% [markdown]
# ```
#
#
#
#
# ```
#
# ### 2.3 if - elif - else语句

# %% [markdown]
# 所以if语句的完整形式就是：
#
# ```python
# if <条件判断1>:
#     <执行1>
# elif <条件判断2>:
#     <执行2>
# elif <条件判断3>:
#     <执行3>
# else:
#     <执行4>
#
# ```

# %% [markdown]
# - if语句执行有个特点，它是从上往下判断
# - 如果在某个判断上是True，把该判断对应的语句执行后，就忽略掉剩下的elif和else
# - 所以，请测试并解释为什么下面的程序打印的是“少年”：

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
age = 15

if age >= 18:
    print('成人')
elif age >= 6:
    print('少年')
elif age >= 5:
    print('小孩')
else:
    print('婴儿')

# %% [markdown]
# ```
#
# ```

# %% [markdown]
# ```
#
# ```
# ### 2.4 if 嵌套

# %% [markdown]
# - 通过学习if的基本用法，已经知道了
#     - 当需要满足条件去做事情的这种情况需要使用if
#     - 当满足条件时做事情A，不满足条件做事情B的这种情况使用if-else
#
# - 想一想：坐火车或者地铁的实际情况是：
#     - 先检查是否有车票之后, 才会进行安检，
#     - 即实际的情况某个判断是再另外一个判断成立的基础上进行的，这样的情况该怎样解决呢？

# %% [markdown]
# if嵌套的格式
# ```python
#  if 条件1:
#
#         满足条件1 做的事情1
#         满足条件1 做的事情2
#         ...(省略)...
#
#         if 条件2:
#             满足条件2 做的事情1
#             满足条件2 做的事情2
#             ...(省略)...
#
# ```

# %% [markdown]
# ![_auto_0](attachment:_auto_0)

# %%
Ticket= int(input("是否有车票？如果有则填写“1”，没有则填写“0”："))

if Ticket == 1:
    print("有车票，请接受检查")
    contraband = int(input("是否有带违禁品？如果有则填写“1”，没有则填写“0”："))   
    
    if contraband == 1:
        print("不能进站")
    elif contraband == 0:
        print("可以进站")
        
elif Ticket == 0:
    print("不能进站")

# %% [markdown]
# 上面的小测试并不完美，仅作为if嵌套的简单例子。

# %% [markdown]
# ```
#
#
#
# ```
# ## 3. 循环结构

# %% [markdown]
# 循环语句的使用场景
#
# 这一天老师让你抄写一百遍"我错了"

# %%
print("我错了")
print("我错了")
print("我错了")
print("我错了")
print("我错了")
print("......")

# %%
i = 1

while i <= 10:
    print("第", i, "次,", "我错了")
    i += 1

# %% [markdown]
# ```
#
#
#
# ```
# ### 3.1 while循环

# %% [markdown]
# 只要while后面的条件判断为True，那么就会一直执行循环体内的语句。

# %% [markdown]
# ```python
# while 条件:
#         条件满足时，做的事情1
#         条件满足时，做的事情2
#         条件满足时，做的事情3
#         ...(省略)...
# ```

# %% [markdown]
# ![_auto_2](attachment:_auto_2)

# %% [markdown]
# **例1：将0到5赋值到i，打印出来并表明该次是第几次循环。**

# %%
i = 1

while i<=5:
    print("当前是第%d次执行循环"%(i))  #字符串的格式化
    print("i=%d"%i)
    i+=1  #加法赋值

# %% [markdown]
# <br/></br>
# **while循环和if语句有什么不同？将上面的while替换成if，观察结果：**

# %%
i = 1

if i<=5:
    print("当前是第%d次执行循环"%(i))
    print("i=%d"%i)
    i+=1

# %% [markdown]
# &emsp;
#
# &emsp;
# **例2：计算1~100的累积和（包含1和100）**

# %%
i = 1
sum1 = 0

while i<=100:
    sum1 += i
    i += 1

print(f"1~100的累积和为:{sum1}")

# %% [markdown]
# ```
#
# ```
# ### 3.2 while循环嵌套

# %% [markdown]
# 使用while循环嵌套打印出九九乘法表：

# %%
i=1          #i是行数
while i<=9:
        j=1  #j是列数
        while j<=i:  #同一行，列数不超过行数
                print("{}*{}= {} ".format(j,i,j*i),end=" ")
                j+=1
        i+=1
        print("")

# %%
i=1          #i是行数
while i<=9:
        j=1  #j是列数
        while j<=i:  #同一行，列数不超过行数
                print("%d*%d=%2d" % (j,i,j*i),end="  ")
                j+=1
        i+=1
        print("")

# %%
i=1          #i是行数
while i<=9:
        j=1  #j是列数
        while j<=i:  #同一行，列数不超过行数
                print("{}*{}={}".ljust(10).format(j,i,j*i),end=" ")
                j+=1
        i+=1
        print("")

# %%
"{}*{}= {}".ljust(10).format(1,2,3*4)

# %%
'12'.ljust(3)

# %%
i=1          #i是行数
while i<=9:
        j=1  #j是列数
        while j<i:  #同一行，列数不超过行数
                print("{}*{}={} ".format(j,i,j*i),end=" ")
                j+=1
        if j==i:
                print("{}*{}={} ".format(j,i,j*i))
        i+=1

# %% [markdown]
# ```
#
# ```
# ### 3.3 for循环

# %% [markdown]
# 像while循环一样，for可以完成循环的功能。
#
# 在Python中 for循环可以遍历任何序列的项目，如一个列表或者一个字符串等。
#
# for循环的格式
#
# ```python
#     for 临时变量 in 列表或者字符串等:
#         循环满足条件时执行的代码
#
# ```

# %%
for i in range(5):
    print(i)

# %%
[i for i in range(5)]

# %%
for i,j in {1:"a",2:"b",3:"c"}.items():
    print(i)
    print(j)
    print("---")

# %% [markdown]
# ```
#
# ```
#
# ### 3.4 for循环嵌套

# %% [markdown]
# 有一个列表a=[1,2,3,[55,66,77,88]],用for循环嵌套的方式遍历该列表，如果列表a的元素为列表，则将元素为列表中的元素逐一输出。

# %%
a=[1,2,3,[55,66,77,88]]

for i in a:
    if type(i)==list :
        for j in i:
            print(j)

# %% [markdown]
# ```
#
#
#
# ```
# ### 3.5 for...else与while...else
# 遍历循环还有一种扩展模式， 使用方法如下：
# ```Python
# for <循环变量> in <遍历结构>:
#     <语句块1>
# else:
#     <语句块2>
# ```
# 同样地，while语句也有相同的扩展

# %% [markdown]
# - 当for循环正常执行之后， 程序会继续执行else语句中内容。
# - else语句只在循环正常执行之后才执行并结束， 可以在<语句块2>中放置判断循环执行情况的语句

# %%
for i in [1,2,0,3]:
    print(i)
else:
    print("没问题")

# %%
for i in [1,2,0,3]:
    print(i)
    break
else:
    print("没问题")

# %%
i=1

while i<=5:
    print(i)
    i+=1
    break
else:
    print("没问题")

# %% [markdown]
# ```
#
# ```
# ## 4. 跳转语句

# %% [markdown]
# ### 4.1 break语句
#
# &emsp;&emsp;break语句可以终止当前的循环，包括while和for在内的所有控制语句。
# <br/>&emsp;&emsp;这就好比你绕圈跑步，一开始打算跑5圈。</br>
# <br/>&emsp;&emsp;跑了2圈半，突然朋友喊你，你就停下来，不跑了，找朋友去了。
# ——结束当前循环</br>
# <br/>&emsp;&emsp;此时，算作你跑了2圈。</br>

# %% [markdown]
# <font color=#DC143C>
# - **break语句跳出了最内层while循环，但仍然继续执行外层循环。每个break语句只有能力跳出当前层次循环。**

# %% [markdown]
# **在for循环中**

# %%
name = '世界杯在召唤我'

for x in name:
    print('----')
    if x == '在': 
         break
    print(x)

print("这句话在for循环后，但是和for循环无关")   #脱离该循环后程序从循环后代码继续续执行

# %%
name = '世界杯在召唤我'

for i in range(3):
    for x in name:
        print('----')
        if x == '在': 
             break       #跳出了最内层while循环，但仍然继续执行外层循环
        print(x)
    print(f"\n——————我是{i+1}次大循环结束之后的优美的分割线——————\n")

print("\n这句话在for循环后，for循环无关\n")

# %% [markdown]
# ```
#
# ```
# **在while循环中**

# %%
i = 0
while i<10:
    i+=1
    print('----')
    if i==5:
        break
    print(i)

# %% [markdown]
# &emsp;
#
# &emsp;
# <font color=#DC143C size=3 >
# **如果是嵌套循环，break语句结束的是哪个循环？**

# %%
for i in range(3):
    for j in range(20,31):
        if j ==25:
            break
        print(j)
    print("----")

# %% [markdown]
# ```
#
#
#
#
# ```
# ### 4.2 continue语句
# - continue的作用：用来结束本次循环，紧接着执行下一次的循环。
# - 这就好比你绕圈跑步，一开始打算跑5圈。
# - 跑了2圈半，发现好像落下钱包在起跑点了，终止跑第二圈。
# - 然后你回到起跑点找钱包，找到钱包，然后继续重新跑，算作从第3圈开始跑。
# - 这里你要注意的是：<font color=#DC143C>
#     - break用来结束当前代码块的最内层循环。
#     - continue用来结束当前代码块的本次循环。

# %% [markdown]
# **在for循环中**

# %%
name = '世界杯在召唤我'

for x in name:
    print('----')
    if x == '在': 
        continue
    print(x)

# %% [markdown]
# ```
#
#
# ```
#
#
# **在while循环中**

# %%
i = 0
while i<10:
    i = i+1
    print('----')
    if i==5:
        continue
    print(i)

# %% [markdown]
# <font color=#DC143C size=4 >
# **注意:**
#
# <font color=#00008B size=3 >
# **break/continue只能用在循环中，除此以外不能单独使用**
#
# **break/continue在嵌套循环中，只对最近的一层循环起作用**

# %% [markdown]
# &emsp;
# &emsp;
# <font color=#DC143C size=3 >
# **如果是嵌套循环，continue语句结束的是哪个循环？**

# %%
for i in range(3):
    for j in range(1,8):
        if j ==5:
            continue
        print(j)
    print("----")

# %% [markdown]
# ### 4.3 pass空语句

# %%
for letter in 'Python':
    if letter == 'h':
        pass
    else:
        print("当前字母 :",letter)

# %% [markdown]
# **如果我们上面的pass不写（或者用注释代替），会报错，因为if语句是不完整的：**
# ```
# 从上面对比可以知道，pass是空语句，是为了保持程序结构的完整性。
# pass 不做任何事情，一般用做占位语句。
# ```
