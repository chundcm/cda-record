# %% [markdown]
# # HeatMap（热力图）

# %% [markdown]
# 热力图主要通过颜色去表现数值的大小，必须要配合 visualMap 组件使用。直角坐标系上必须要使用两个类目轴。

# %%
import random
from pyecharts import HeatMap

x_axis = [
    "12a", "1a", "2a", "3a", "4a", "5a", "6a", "7a", "8a", "9a", "10a", "11a",
    "12p", "1p", "2p", "3p", "4p", "5p", "6p", "7p", "8p", "9p", "10p", "11p"]
y_axis = ["Saturday", "Friday", "Thursday", "Wednesday", "Tuesday", "Monday", "Sunday"]
data = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]

heatmap = HeatMap()
heatmap.add("热力图直角坐标系", x_axis, y_axis, data,
            is_visualmap=True, visual_text_color="#000", visual_orient="horizontal",
            visual_pos="left", visual_bottom="20%")
heatmap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f8c7f3083e2f4ea6935340bcecf27797" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f8c7f3083e2f4ea6935340bcecf27797 = echarts.init(document.getElementById('f8c7f3083e2f4ea6935340bcecf27797'), 'light', {renderer: 'canvas'});
#
# var option_f8c7f3083e2f4ea6935340bcecf27797 = {
#     "xAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "inverse": false,
#             "type": "category",
#             "axisLabel": {
#                 "interval": "auto",
#                 "margin": 8,
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "splitArea": {
#                 "show": true
#             },
#             "data": [
#                 "12a",
#                 "1a",
#                 "2a",
#                 "3a",
#                 "4a",
#                 "5a",
#                 "6a",
#                 "7a",
#                 "8a",
#                 "9a",
#                 "10a",
#                 "11a",
#                 "12p",
#                 "1p",
#                 "2p",
#                 "3p",
#                 "4p",
#                 "5p",
#                 "6p",
#                 "7p",
#                 "8p",
#                 "9p",
#                 "10p",
#                 "11p"
#             ],
#             "show": true
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "nameLocation": "middle",
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameGap": 25,
#             "inverse": false,
#             "type": "category",
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "splitArea": {
#                 "show": true
#             },
#             "data": [
#                 "Saturday",
#                 "Friday",
#                 "Thursday",
#                 "Wednesday",
#                 "Tuesday",
#                 "Monday",
#                 "Sunday"
#             ],
#             "show": true
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "left": "center",
#             "top": "top",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u70ed\u529b\u56fe\u76f4\u89d2\u5750\u6807\u7cfb"
#             ],
#             "show": true
#         }
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "data": [
#                 [
#                     0,
#                     0,
#                     35
#                 ],
#                 [
#                     0,
#                     1,
#                     32
#                 ],
#                 [
#                     0,
#                     2,
#                     18
#                 ],
#                 [
#                     0,
#                     3,
#                     7
#                 ],
#                 [
#                     0,
#                     4,
#                     1
#                 ],
#                 [
#                     0,
#                     5,
#                     41
#                 ],
#                 [
#                     0,
#                     6,
#                     21
#                 ],
#                 [
#                     1,
#                     0,
#                     48
#                 ],
#                 [
#                     1,
#                     1,
#                     24
#                 ],
#                 [
#                     1,
#                     2,
#                     46
#                 ],
#                 [
#                     1,
#                     3,
#                     35
#                 ],
#                 [
#                     1,
#                     4,
#                     50
#                 ],
#                 [
#                     1,
#                     5,
#                     28
#                 ],
#                 [
#                     1,
#                     6,
#                     16
#                 ],
#                 [
#                     2,
#                     0,
#                     39
#                 ],
#                 [
#                     2,
#                     1,
#                     40
#                 ],
#                 [
#                     2,
#                     2,
#                     28
#                 ],
#                 [
#                     2,
#                     3,
#                     40
#                 ],
#                 [
#                     2,
#                     4,
#                     20
#                 ],
#                 [
#                     2,
#                     5,
#                     43
#                 ],
#                 [
#                     2,
#                     6,
#                     31
#                 ],
#                 [
#                     3,
#                     0,
#                     37
#                 ],
#                 [
#                     3,
#                     1,
#                     36
#                 ],
#                 [
#                     3,
#                     2,
#                     12
#                 ],
#                 [
#                     3,
#                     3,
#                     22
#                 ],
#                 [
#                     3,
#                     4,
#                     43
#                 ],
#                 [
#                     3,
#                     5,
#                     28
#                 ],
#                 [
#                     3,
#                     6,
#                     44
#                 ],
#                 [
#                     4,
#                     0,
#                     9
#                 ],
#                 [
#                     4,
#                     1,
#                     19
#                 ],
#                 [
#                     4,
#                     2,
#                     9
#                 ],
#                 [
#                     4,
#                     3,
#                     2
#                 ],
#                 [
#                     4,
#                     4,
#                     10
#                 ],
#                 [
#                     4,
#                     5,
#                     28
#                 ],
#                 [
#                     4,
#                     6,
#                     0
#                 ],
#                 [
#                     5,
#                     0,
#                     38
#                 ],
#                 [
#                     5,
#                     1,
#                     41
#                 ],
#                 [
#                     5,
#                     2,
#                     38
#                 ],
#                 [
#                     5,
#                     3,
#                     17
#                 ],
#                 [
#                     5,
#                     4,
#                     19

# %%
import datetime
import random
from pyecharts import HeatMap

begin, end = datetime.date(2017, 1, 1), datetime.date(2017, 12, 31)
data = [[str(begin + datetime.timedelta(days=i)),
        random.randint(1000, 25000)] for i in range((end - begin).days + 1)]
heatmap = HeatMap("日历热力图示例", "某人 2017 年微信步数情况", width=1000)
heatmap.add("", data,
            is_calendar_heatmap=True,
            is_visualmap=True,
            visual_orient="horizontal", visual_pos="center", visual_top="70%", 
            visual_text_color='#000', visual_range_text=['', ''],
            visual_range=[1000, 25000],
            calendar_cell_size=['auto', 30],
            visual_split_number=3,  # 分段型中分割的段数，在设置为分段型时生效。默认分为 5 段。
            calendar_date_range="2017",
            is_piecewise=True,  # 是否将组件转换为分段型（默认为连续型），默认为 False
           )
heatmap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="89d31bdf784d4b148aa0f697e2b4d22a" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_89d31bdf784d4b148aa0f697e2b4d22a = echarts.init(document.getElementById('89d31bdf784d4b148aa0f697e2b4d22a'), 'light', {renderer: 'canvas'});
#
# var option_89d31bdf784d4b148aa0f697e2b4d22a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "orient": "horizontal",
#         "showLabel": true,
#         "min": 1000,
#         "calculable": true,
#         "text": [
#             "",
#             ""
#         ],
#         "max": 25000,
#         "splitNumber": 3,
#         "left": "center",
#         "top": "70%",
#         "textStyle": {
#             "color": "#000"
#         },
#         "type": "piecewise",
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         }
#     },
#     "legend": [
#         {
#             "orient": "horizontal",
#             "left": "center",
#             "top": "top",
#             "selectedMode": "multiple",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 ""
#             ],
#             "show": true
#         }
#     ],
#     "calendar": {
#         "cellSize": [
#             "auto",
#             30
#         ],
#         "range": "2017"
#     },
#     "series": [
#         {
#             "data": [
#                 [
#                     "2017-01-01",
#                     7853
#                 ],
#                 [
#                     "2017-01-02",
#                     2255
#                 ],
#                 [
#                     "2017-01-03",
#                     11215
#                 ],
#                 [
#                     "2017-01-04",
#                     10708
#                 ],
#                 [
#                     "2017-01-05",
#                     11569
#                 ],
#                 [
#                     "2017-01-06",
#                     20629
#                 ],
#                 [
#                     "2017-01-07",
#                     2564
#                 ],
#                 [
#                     "2017-01-08",
#                     12976
#                 ],
#                 [
#                     "2017-01-09",
#                     21010
#                 ],
#                 [
#                     "2017-01-10",
#                     15045
#                 ],
#                 [
#                     "2017-01-11",
#                     6089
#                 ],
#                 [
#                     "2017-01-12",
#                     1759
#                 ],
#                 [
#                     "2017-01-13",
#                     10486
#                 ],
#                 [
#                     "2017-01-14",
#                     3864
#                 ],
#                 [
#                     "2017-01-15",
#                     6284
#                 ],
#                 [
#                     "2017-01-16",
#                     21468
#                 ],
#                 [
#                     "2017-01-17",
#                     7498
#                 ],
#                 [
#                     "2017-01-18",
#                     8169
#                 ],
#                 [
#                     "2017-01-19",
#                     15978
#                 ],
#                 [
#                     "2017-01-20",
#                     4419
#                 ],
#                 [
#                     "2017-01-21",
#                     16347
#                 ],
#                 [
#                     "2017-01-22",
#                     12706
#                 ],
#                 [
#                     "2017-01-23",
#                     10718
#                 ],
#                 [
#                     "2017-01-24",
#                     21912
#                 ],
#                 [
#                     "2017-01-25",
#                     9137
#                 ],
#                 [
#                     "2017-01-26",
#                     11570
#                 ],
#                 [
#                     "2017-01-27",
#                     15630
#                 ],
#                 [
#                     "2017-01-28",
#                     11587
#                 ],
#                 [
#                     "2017-01-29",
#                     20568
#                 ],
#                 [
#                     "2017-01-30",
#                     23204
#                 ],
#                 [
#                     "2017-01-31",
#                     20737
#                 ],
#                 [
#                     "2017-02-01",
#                     21456
#                 ],
#                 [
#                     "2017-02-02",
#                     1456
#                 ],
#                 [
#                     "2017-02-03",
#                     2600
#                 ],
#                 [
#                     "2017-02-04",
#                     15862
#                 ],
#                 [
#                     "2017-02-05",
#                     13052
#                 ],
#                 [
#                     "2017-02-06",
#                     4188
#                 ],
#                 [
#                     "2017-02-07",
#                     15024
#                 ],
#                 [
#                     "2017-02-08",
#                     20015
#                 ],
#                 [
#                     "2017-02-09",
#                     23173
#                 ],
#                 [
#                     "2017-02-10",
#                     24373
#                 ],
#                 [
#                     "2017-02-11",
#                     1013
#                 ],
#                 [
#                     "2017-02-12",
#                     20115
#                 ],
#                 [
#                     "2017-02-13",
#                     17955
#                 ],
#                 [
#                     "2017-02-14",
#                     10820
#                 ],
#                 [
#                     "2017-02-15",
#                     1445
#                 ],
#                 [
#                     "2017-02-16",
#                     1818
#                 ],
#                 [
#                     "2017-02-17",
#                     16963
#                 ],
#                 [
#                     "2017-02-18",
#                     16124
#                 ],
#                 [
#                     "2017-02-19",
#                     19820
#                 ],
#                 [
#                     "2017-02-20",
#                     20233
#                 ],
#                 [
#                     "2017-02-21",
#                     21695
#                 ],
#                 [
#                     "2017-02-22",
#                     7207
#                 ],
#                 [
#                     "2017-02-23",
#                     18382
#                 ],
#                 [
#                     "2017-02-24",
#                     22339
#                 ],
#                 [
#                     "2017-02-25",
#                     13850
#                 ],
#                 [
#                     "2017-02-26",
#                     19568
#                 ],
#                 [
#                     "2017-02-27",
#                     23471
#                 ],
#                 [
#                     "2017-02-28",
#                     18690
#                 ],
#                 [
#                     "2017-03-01",
#                     1958
#                 ],
#                 [
#                     "2017-03-02",
#                     19217
#                 ],
#                 [
#                     "2017-03-03",
#                     5905
