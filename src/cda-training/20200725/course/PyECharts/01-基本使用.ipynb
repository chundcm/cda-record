# %% [markdown]
# ## pyecharts 库的基本使用用法

# %% [markdown]
# # 渲染图表

# %% [markdown]
# 安装pyecharts

# %%
# !pip install pyecharts

# %%
# 导入pyecharts
import pyecharts
# 检查pyecharts版本
pyecharts.__version__
# Out:
# '0.5.5'

# %%
print(dir(pyecharts))
# Out:
# ['Bar', 'Bar3D', 'Boxplot', 'Candlestick', 'EffectScatter', 'Funnel', 'Gauge', 'Geo', 'GeoLines', 'Graph', 'Grid', 'HeatMap', 'Kline', 'Line', 'Line3D', 'Liquid', 'Map', 'Overlap', 'Page', 'Parallel', 'Pie', 'Polar', 'Radar', 'Sankey', 'Scatter', 'Scatter3D', 'Style', 'ThemeRiver', 'Timeline', 'TreeMap', 'WordCloud', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_version', 'base', 'chart', 'charts', 'conf', 'configure', 'constants', 'custom', 'datasets', 'echarts', 'enable_nteract', 'engine', 'exceptions', 'js_extensions', 'jupyter_image', 'online', 'utils']

# %% [markdown]
# ### 第一个示例

# %%
# 从pyecharts库中导入Bar类, 图类
from pyecharts import Bar

bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])

# %%
# 该行只为了打印配置项，方便调试时使用
# bar.print_echarts_options()

# %%
# 生成本地 HTML 文件，默认名为“render.html”
bar.render()

# %%
# # 生成本地 HTML 文件，命名为“我的第一个图表.html”
bar.render(path="我的第一个图表.html")

# %%
# 在jupyter notebook中打印图
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="34647f877fae4d96abaf8ef72e4d6829" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_34647f877fae4d96abaf8ef72e4d6829 = echarts.init(document.getElementById('34647f877fae4d96abaf8ef72e4d6829'), 'light', {renderer: 'canvas'});
#
# var option_34647f877fae4d96abaf8ef72e4d6829 = {
#     "tooltip": {
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameGap": 25,
#             "splitLine": {
#                 "show": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u670d\u88c5"
#             ],
#             "show": true,
#             "top": "top"
#         }
#     ],
#     "title": [
#         {
#             "left": "auto",
#             "text": "\u6211\u7684\u7b2c\u4e00\u4e2a\u56fe\u8868",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "top": "auto"
#         }
#     ],
#     "toolbox": {
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "top": "center"
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameGap": 25,
#             "splitLine": {
#                 "show": true
#             }
#         }
#     ],
#     "series": [
#         {
#             "seriesId": 4366174,
#             "type": "bar",
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "name": "\u670d\u88c5",
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "barCategoryGap": "20%"
#         }
#     ],
#     "series_id": 4366174
# };
# myChart_34647f877fae4d96abaf8ef72e4d6829.setOption(option_34647f877fae4d96abaf8ef72e4d6829);
#
#     });
# </script>

# %% [markdown]
# * add()
#
# 主要方法，用于添加图表的数据和设置各种配置项
#
# * print_echarts_options()
#
# 打印输出图表的所有配置项
#
# * render()
#
# 默认将会在根目录下生成一个 render.html 的文件，支持 path 参数，设置文件保存位置，如 render(r"e:\my_first_chart.html")，文件用浏览器打开。
#
# Note： 可以按右边的下载按钮将图片下载到本地，如果想要提供更多实用工具按钮，请在 add() 中设置 is_more_utils 为 True

# %%
from pyecharts import Bar

bar = Bar("我的第一个图表", "这里是副标题")
# 自 0.5.2+ 起，pyecharts 支持更换主题。echarts 自带 dark 主题， pyecharts 也就自带了 dark，默认主题是shine
bar.use_theme('dark')
bar.add("服装", 
        ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"],
        [5, 20, 36, 10, 75, 90],
        is_toolbox_show=True,
        is_more_utils=True)
# bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6fa046543a8a41349d444c4ac52e1d70" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6fa046543a8a41349d444c4ac52e1d70 = echarts.init(document.getElementById('6fa046543a8a41349d444c4ac52e1d70'), 'dark', {renderer: 'canvas'});
#
# var option_6fa046543a8a41349d444c4ac52e1d70 = {
#     "series_id": 3034149,
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "magicType": {
#                 "title": {
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "tiled": "\u5e73\u94fa",
#                     "stack": "\u5806\u53e0",
#                     "line": "\u6298\u7ebf\u56fe"
#                 },
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ]
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             },
#             "dataZoom": {
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
#             "text": "\u6211\u7684\u7b2c\u4e00\u4e2a\u56fe\u8868",
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "type": "category",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u670d\u88c5"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "markLine": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 3034149,
#             "type": "bar",
#             "name": "\u670d\u88c5"
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "color": [],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click"
#     }
# };
# myChart_6fa046543a8a41349d444c4ac52e1d70.setOption(option_6fa046543a8a41349d444c4ac52e1d70);
#
#     });
# </script>

# %% [markdown]
# ## 自定义主题：扩展主题插件，多样化图表配色
# 自 0.5.2+ 起，pyecharts 支持更换主体色系。
# ### 如何获得更多主题
# echarts-themes-pypkg 提供了 vintage, macarons, infographic, shine 和 roma 主题。

# %% [markdown]
# 安装主题插件

# %%
# !pip install echarts-themes-pypkg

# %%
from pyecharts import Bar, Page

page = Page()
for t in ['dark','vintage','macarons','infographic','shine','roma']:
    bar = Bar(t)
    bar.use_theme(t)
    bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
    page.add(bar)
page.render(path="pyecharts 自定义主题主题展示.html")
page
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'vintage': '/nbextensions/echarts-themes-js/vintage', 'macarons': '/nbextensions/echarts-themes-js/macarons', 'infographic': '/nbextensions/echarts-themes-js/infographic', 'shine': '/nbextensions/echarts-themes-js/shine', 'roma': '/nbextensions/echarts-themes-js/roma'
#         }
#     });
# </script>
#     <div id="0f52a834430146ec802ec823168f08eb" style="width:800px;height:400px;"></div>
#     <div id="41881411cd9c43d7a461afa2a86a996f" style="width:800px;height:400px;"></div>
#     <div id="7823bb602f284636bd604c6190d12480" style="width:800px;height:400px;"></div>
#     <div id="f3620ad1e28b4283a80fe92a7d554b7b" style="width:800px;height:400px;"></div>
#     <div id="7f6565e769af453cbd619c65859cb583" style="width:800px;height:400px;"></div>
#     <div id="41fe9b18abe741cdb0834c6712bc0daa" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'vintage', 'macarons', 'infographic', 'shine', 'roma'], function(echarts) {
#
# var myChart_0f52a834430146ec802ec823168f08eb = echarts.init(document.getElementById('0f52a834430146ec802ec823168f08eb'), 'dark', {renderer: 'canvas'});
#
# var option_0f52a834430146ec802ec823168f08eb = {
#     "series_id": 2616637,
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
#             "text": "dark",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "top": "auto"
#         }
#     ],
#     "xAxis": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "type": "category",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u670d\u88c5"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "markLine": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 2616637,
#             "type": "bar",
#             "name": "\u670d\u88c5"
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "color": [],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click"
#     }
# };
# myChart_0f52a834430146ec802ec823168f08eb.setOption(option_0f52a834430146ec802ec823168f08eb);
#
#
# var myChart_41881411cd9c43d7a461afa2a86a996f = echarts.init(document.getElementById('41881411cd9c43d7a461afa2a86a996f'), 'vintage', {renderer: 'canvas'});
#
# var option_41881411cd9c43d7a461afa2a86a996f = {
#     "series_id": 4979456,
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
#             "text": "vintage",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "top": "auto"
#         }
#     ],
#     "xAxis": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "type": "category",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u670d\u88c5"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "markLine": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },

# %% [markdown]
# ### 图形绘制过程

# %% [markdown]
# 基本上所有的图表类型都是这样绘制的：
# 1. chart_name = Type()  初始化具体类型图表
#     * bar = Bar("我的第一个图表", "这里是副标题")
# 2. add()           添加数据及配置项
#     * bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
# 3. render()         生成本地文件（html/svg/jpeg/png/pdf/gif）
#     * bar.render(path="我的第一个图表.html")
# 4. add()           数据一般为两个列表（长度一致），如果你的数据是字典或者是带元组的字典。可利用 cast() 方法转换
#     * cast(seq)：转换数据序列，将带字典和元组类型的序列转换为 k_lst,v_lst 两个列表
#         * 元组列表
#             * [(A1, B1), (A2, B2), (A3, B3), (A4, B4)] --> k_lst[ A[i1, i2...] ], v_lst[ B[i1, i2...] ]
#         * 字典列表
#             * [{A1: B1}, {A2: B2}, {A3: B3}, {A4: B4}] --> k_lst[ A[i1, i2...] ], v_lst[ B[i1, i2...] ]
#         * 字典
#             * {A1: B1, A2: B2, A3: B3, A4: B4} -- > k_lst[ A[i1, i2...] ], v_lst[ B[i1, i2...] ]

# %%
# 通过具体图类自定义主题只是暂时的设置，如果想更换运行环境内所有图表主题，可做如下操作实现
from pyecharts import configure
configure(global_theme='dark')

# %%
from pyecharts import Bar

bar = Bar("我的第一个图表", "这里是副标题")
# 元组列表
# data = [('衬衫', 5), ('羊毛衫', 20), ('雪纺衫', 36), ('裤子', 10), ('高跟鞋', 75), ('袜子', 90)]
# 字典
data = {'羊毛衫': 20, '衬衫': 5, '袜子': 90, '裤子': 10, '雪纺衫': 36, '高跟鞋': 75}
# 字典列表
# data = [{'羊毛衫': 20}, {'衬衫': 5}, {'袜子': 90}, {'裤子': 10}, {'雪纺衫': 36}, {'高跟鞋': 75}]
attr, value = bar.cast(data)
bar.add("服装", attr, value)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3053199e650d44e3bd119d6f0c83e091" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3053199e650d44e3bd119d6f0c83e091 = echarts.init(document.getElementById('3053199e650d44e3bd119d6f0c83e091'), 'dark', {renderer: 'canvas'});
#
# var option_3053199e650d44e3bd119d6f0c83e091 = {
#     "series_id": 6367046,
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
#             "text": "\u6211\u7684\u7b2c\u4e00\u4e2a\u56fe\u8868",
#             "subtext": "\u8fd9\u91cc\u662f\u526f\u6807\u9898",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "data": [
#                 "\u7f8a\u6bdb\u886b",
#                 "\u886c\u886b",
#                 "\u889c\u5b50",
#                 "\u88e4\u5b50",
#                 "\u96ea\u7eba\u886b",
#                 "\u9ad8\u8ddf\u978b"
#             ],
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "type": "category",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u670d\u88c5"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 20,
#                 5,
#                 90,
#                 10,
#                 36,
#                 75
#             ],
#             "markLine": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 6367046,
#             "type": "bar",
#             "name": "\u670d\u88c5"
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "color": [],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click"
#     }
# };
# myChart_3053199e650d44e3bd119d6f0c83e091.setOption(option_3053199e650d44e3bd119d6f0c83e091);
#
#     });
# </script>

# %% [markdown]
# ### 多次显示图表

# %% [markdown]
# 从 v0.4.0+ 开始，pyecharts 重构了渲染的内部逻辑，改善效率。推荐使用以下方式显示多个图表。

# %%
from pyecharts import Bar, Line
from pyecharts.engine import create_default_environment

bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])

line = Line("我的第一个图表", "这里是副标题")
line.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])

# 为渲染创建一个默认配置环境
# create_default_environment(filet_ype)
# file_type: 'html', 'svg', 'png', 'jpeg', 'gif' or 'pdf'
env = create_default_environment("html")

env.render_chart_to_file(bar, path='bar.html')
env.render_chart_to_file(line, path='line.html')

# %% [markdown]
# 相比第一个例子，该代码只是使用同一个引擎对象，减少了部分重复操作，速度有所提高。

# %% [markdown]
# ### 使用Pandas&Numpy处理数据

# %%
import pandas as pd
import numpy as np
np.random.seed(1026)
from pyecharts import Bar

index = pd.date_range('1/1/2017', periods=8, freq='M')
profit = np.random.randint(0, 100, 8)
loss = np.random.randint(-100, 0, 8)
_index = [i for i in index.format()]

# %%
bar = Bar('损益情况图')
bar.add('收益', _index, profit)
bar.add('损失', _index, loss, is_more_utils=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shine': '/nbextensions/echarts-themes-js/shine'
#         }
#     });
# </script>
#     <div id="bde8fe57e06f44fa9f329ddb3d0e13b5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'shine'], function(echarts) {
#
# var myChart_bde8fe57e06f44fa9f329ddb3d0e13b5 = echarts.init(document.getElementById('bde8fe57e06f44fa9f329ddb3d0e13b5'), 'shine', {renderer: 'canvas'});
#
# var option_bde8fe57e06f44fa9f329ddb3d0e13b5 = {
#     "series_id": 5205454,
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "feature": {
#             "magicType": {
#                 "title": {
#                     "bar": "\u67f1\u72b6\u56fe",
#                     "tiled": "\u5e73\u94fa",
#                     "stack": "\u5806\u53e0",
#                     "line": "\u6298\u7ebf\u56fe"
#                 },
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ]
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             },
#             "dataZoom": {
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "show": true
#             }
#         },
#         "top": "center"
#     },
#     "title": [
#         {
#             "text": "\u635f\u76ca\u60c5\u51b5\u56fe",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto",
#             "top": "auto"
#         }
#     ],
#     "xAxis": [
#         {
#             "data": [
#                 "2017-01-31",
#                 "2017-02-28",
#                 "2017-03-31",
#                 "2017-04-30",
#                 "2017-05-31",
#                 "2017-06-30",
#                 "2017-07-31",
#                 "2017-08-31"
#             ],
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "rotate": 0,
#                 "margin": 8,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "type": "category",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6536\u76ca",
#                 "\u635f\u5931"
#             ],
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "orient": "horizontal",
#             "top": "top",
#             "selectedMode": "multiple",
#             "show": true
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 19.0,
#                 65.0,
#                 26.0,
#                 84.0,
#                 63.0,
#                 74.0,
#                 2.0,
#                 2.0
#             ],
#             "markLine": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 5205454,
#             "type": "bar",
#             "name": "\u6536\u76ca"
#         },
#         {
#             "data": [
#                 -48.0,
#                 -84.0,
#                 -81.0,
#                 -11.0,
#                 -21.0,
#                 -5.0,
#                 -94.0,
#                 -37.0
#             ],
#             "markLine": {
#                 "data": []
#             },
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "seriesId": 5205454,
#             "type": "bar",
#             "name": "\u635f\u5931"
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "rotate": 0,
#                 "interval": "auto"
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "type": "value",
#             "nameGap": 25,
#             "show": true
#         }
#     ],
#     "color": [],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "axisPointer": {
#             "type": "line"
#         },
#         "borderWidth": 0,
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click"
#     }
# };
# myChart_bde8fe57e06f44fa9f329ddb3d0e13b5.setOption(option_bde8fe57e06f44fa9f329ddb3d0e13b5);
#
#     });
# </script>

# %% [markdown]
# # 图表配置

# %% [markdown]
# pyecharts 的主要配置文档，介绍关于 pyecharts 的详细配置项

# %% [markdown]
# **图形初始化**：图表类初始化所接受的参数（所有类型的图表都一样）。
# ___
# ** Bar(title, subtitle, width, height, title_pos, title_top, title_color, subtitle_color, title_text_size, subtitle_text_size, background_color, page_title, renderer) **
# * title -> str
#     * 主标题文本，支持 \n 换行，默认为 ""
# * subtitle -> str
#     * 副标题文本，支持 \n 换行，默认为 ""
# * width -> int
#     * 画布宽度，默认为 800（px）
# * height -> int
#     * 画布高度，默认为 400（px）
# * title_pos -> str/int
#     * 标题距离左侧距离，默认为'left'，有'auto', 'left', 'right', 'center'可选，也可为百分比或整数
# * title_top -> str/int
#     * 标题距离顶部距离，默认为'top'，有'top', 'middle', 'bottom'可选，也可为百分比或整数
# * title_color -> str
#     * 主标题文本颜色，默认为 '#000'
# * subtitle_color -> str
#     * 副标题文本颜色，默认为 '#aaa'
# * title_text_size -> int
#     * 主标题文本字体大小，默认为 18
# * subtitle_text_size -> int
#     * 副标题文本字体大小，默认为 12
# * background_color -> str
#     * 画布背景颜色，默认为 '#fff'
# * page_title -> str
#     * 指定生成的 html 文件中 title标签的值。默认为'Echarts'
# * renderer -> str
#     * 指定使用渲染方式，有 'svg' 和 'canvas' 可选，默认为 'canvas'。3D 图仅能使用 'canvas'。

# %% [markdown]
# RGB颜色参考：http://tool.oschina.net/commons?type=3

# %%
# 更换运行环境内所有图表主题为默认主题
from pyecharts import configure
configure(global_theme='shine')

# %%
import pandas as pd
import numpy as np
np.random.seed(1026)
from pyecharts import Bar

index = pd.date_range('1/1/2017', periods=15, freq='M')
profit = np.random.randint(0, 100, 15)
loss = np.random.randint(-100, 0, 15)
_index = [i for i in index.format()]

bar = Bar(title='损益情况图', subtitle='--为测试图形初始化参数', 
          width=900, height=400,
          title_pos='10%', title_top='2%',
          title_color='#00008B', subtitle_color='#008B8B',
          title_text_size=20, subtitle_text_size=15,
          background_color='#CDC9C9',
          page_title='PyECharts',
          renderer='svg')

bar.add('收益', _index, profit)
bar.add('损失', _index, loss, is_more_utils=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shine': '/nbextensions/echarts-themes-js/shine'
#         }
#     });
# </script>
#     <div id="3337a786eaae498fa3f909452f66209d" style="width:900px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'shine'], function(echarts) {
#
# var myChart_3337a786eaae498fa3f909452f66209d = echarts.init(document.getElementById('3337a786eaae498fa3f909452f66209d'), 'shine', {renderer: 'svg'});
#
# var option_3337a786eaae498fa3f909452f66209d = {
#     "legend": [
#         {
#             "left": "center",
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u6536\u76ca",
#                 "\u635f\u5931"
#             ],
#             "show": true,
#             "top": "top"
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameGap": 25,
#             "splitLine": {
#                 "show": true
#             }
#         }
#     ],
#     "backgroundColor": "#CDC9C9",
#     "tooltip": {
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "title": [
#         {
#             "left": "10%",
#             "text": "\u635f\u76ca\u60c5\u51b5\u56fe",
#             "textStyle": {
#                 "color": "#00008B",
#                 "fontSize": 20
#             },
#             "subtextStyle": {
#                 "color": "#008B8B",
#                 "fontSize": 15
#             },
#             "subtext": "--\u4e3a\u6d4b\u8bd5\u56fe\u5f62\u521d\u59cb\u5316\u53c2\u6570",
#             "top": "2%"
#         }
#     ],
#     "toolbox": {
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "magicType": {
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "show": true,
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa",
#                     "bar": "\u67f1\u72b6\u56fe"
#                 }
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "back": "\u7f29\u653e\u8fd8\u539f",
#                     "zoom": "\u533a\u57df\u7f29\u653e"
#                 }
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "top": "center"
#     },
#     "color": [],
#     "xAxis": [
#         {
#             "type": "category",
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "2017-01-31",
#                 "2017-02-28",
#                 "2017-03-31",
#                 "2017-04-30",
#                 "2017-05-31",
#                 "2017-06-30",
#                 "2017-07-31",
#                 "2017-08-31",
#                 "2017-09-30",
#                 "2017-10-31",
#                 "2017-11-30",
#                 "2017-12-31",
#                 "2018-01-31",
#                 "2018-02-28",
#                 "2018-03-31"
#             ],
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameGap": 25,
#             "splitLine": {
#                 "show": false
#             }
#         }
#     ],
#     "series_id": 6115503,
#     "series": [
#         {
#             "seriesId": 6115503,
#             "type": "bar",
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "name": "\u6536\u76ca",
#             "data": [
#                 19.0,
#                 65.0,
#                 26.0,
#                 84.0,
#                 63.0,
#                 74.0,
#                 2.0,
#                 2.0,
#                 52.0,
#                 16.0,
#                 19.0,
#                 89.0,
#                 79.0,
#                 95.0,
#                 6.0
#             ],
#             "barCategoryGap": "20%"
#         },
#         {
#             "seriesId": 6115503,
#             "type": "bar",
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "name": "\u635f\u5931",
#             "data": [
#                 -37.0,
#                 -61.0,
#                 -67.0,
#                 -79.0,
#                 -58.0,
#                 -6.0,
#                 -91.0,
#                 -51.0,
#                 -47.0,
#                 -19.0,
#                 -77.0,
#                 -41.0,
#                 -88.0,
#                 -47.0,
#                 -87.0
#             ],
#             "barCategoryGap": "20%"
#         }
#     ]
# };
# myChart_3337a786eaae498fa3f909452f66209d.setOption(option_3337a786eaae498fa3f909452f66209d);
#
#     });
# </script>

# %% [markdown]
# **通用配置项**：通用配置项均在 add() 中设置
# * xyAxis：直角坐标系中的 x、y 轴(Line、Bar、Scatter、EffectScatter、Kline)
# ___
# * dataZoom：dataZoom 组件用于区域缩放，从而能自由关注细节的数据信息，或者概览数据整体，或者去除离群点的影响。(Line、Bar、Scatter、EffectScatter、Kline、Boxplot)
#     * is_datazoom_show -> bool
#         * 是否使用区域缩放组件，默认为 False
#     * datazoom_type -> str
#         * 区域缩放组件类型，默认为'slider'，有'slider', 'inside', 'both'可选
#     * datazoom_range -> list
#         * 区域缩放的范围，默认为[50, 100]
#     * datazoom_orient -> str
#         * datazoom 组件在直角坐标系中的方向，默认为 'horizontal'，效果显示在 x 轴。如若设置为 'vertical' 的话效果显示在 y 轴。
# ___
# * legend：图例组件。图例组件展现了不同系列的标记(symbol)，颜色和名字。可以通过点击图例控制哪些系列不显示。
#     * is_legend_show -> bool
#         * 是否显示顶端图例，默认为 True
#     * legend_orient -> str
#         * 图例列表的布局朝向，默认为'horizontal'，有'horizontal', 'vertical'可选
#     * legend_pos -> str
#         * 图例组件离容器左侧的距离，默认为'center'，有'left', 'center', 'right'可选，也可以为百分数，如"%60"
#     * legend_top -> str
#         * 图例组件离容器上侧的距离，默认为'top'，有'top', 'center', 'bottom'可选，也可以为百分数，如"%60"
#     * legend_selectedmode -> str/bool
#         * 图例选择的模式，控制是否可以通过点击图例改变系列的显示状态。默认为'multiple'，可以设成 'single' 或者 'multiple' 使用单选或者多选模式。也可以设置为 False 关闭显示状态。
#     * legend_text_size -> int
#         * 图例名称字体大小
#     * legend_text_color -> str
#         * 图例名称字体颜色
# ___
# * label：图形上的文本标签，可用于说明图形的一些数据信息，比如值，名称等。
#     * is_label_show -> bool
#         * 是否正常显示标签，默认不显示。标签即各点的数据项信息
# ___
# * lineStyle：带线图形的线的风格选项(Line、Polar、Radar、Graph、Parallel)
#     * line_width -> int
#         * 线的宽度，默认为 1
#     * line_opacity -> float
#         * 线的透明度，0 为完全透明，1 为完全不透明。默认为 1
#     * line_curve -> float
#         * 线的弯曲程度，0 为完全不弯曲，1 为最弯曲。默认为 0
#     * line_type -> str
#         * 线的类型，有'solid', 'dashed', 'dotted'可选。默认为'solid'
#     * line_color -> str
#         * 线的颜色
# ___
# * grid3D：3D笛卡尔坐标系组配置项，适用于 3D 图形。（Bar3D, Line3D, Scatter3D)
# ___
# * axis3D：3D 笛卡尔坐标系 X，Y，Z 轴配置项，适用于 3D 图形。（Bar3D, Line3D, Scatter3D)
# ___
# * visualMap：是视觉映射组件，用于进行『视觉编码』，也就是将数据映射到视觉元素（视觉通道）
# ___
# * markLine & markPoint：图形标记组件，用于标记指定的特殊数据，有标记线和标记点两种。（Bar、Line、Kline）
# ___
# * tooltip：提示框组件，用于移动或点击鼠标时弹出数据内容
# ___
# * toolbox：右侧实用工具箱
#     * is_toolbox_show -> bool
#         * 指定是否显示右侧实用工具箱，默认为 True。
#     * is_more_utils -> bool
#         * 指定是否提供更多的实用工具按钮。默认只提供『数据视图』和『下载』按钮

# %%
import pandas as pd
import numpy as np
np.random.seed(1026)
from pyecharts import Line

profit = np.random.randint(100, 1000, 52).cumsum()
index = ['{}周'.format(i) for i in range(1,53)]

line = Line(title='累计收益图', subtitle='--为测试通用配置项参数', width=1200)
line.add('累计收益', index, profit, is_more_utils=True,
#          is_convert=True,
#          is_xaxislabel_align=True,
#          is_xaxis_inverse=True,
#          is_yaxis_show=False,
         is_splitline_show=False,
         xaxis_interval=2,
         xaxis_margin=10,
         xaxis_name='周数', xaxis_name_size=16, xaxis_name_gap=35, xaxis_name_pos='middle',
#          xaxis_pos='top',  # x 坐标轴位置，有'top','bottom'可选
         xaxis_rotate=30,  # x 轴刻度标签旋转的角度，默认为 0，即不旋转。旋转的角度从 -90 度到 90 度。
         yaxis_name='累计收益', yaxis_name_size=16, yaxis_name_gap=50, yaxis_name_pos='middle',  # start, middle, end
         
#          datazoom
         is_datazoom_show=True,
         datazoom_type='both',  # 区域缩放组件类型，默认为'slider'，有'slider', 'inside', 'both'可选
         datazoom_range=[20,50],  # 区域缩放的范围，默认为[50, 100]
         
#          label：图形上的文本标签，可用于说明图形的一些数据信息，比如值，名称等。
         is_label_show=True,
#          label_formatter='{b} - {c}',
         
#          lineStyle：带线图形的线的风格选项(Line、Polar、Radar、Graph、Parallel)
         line_width=5,
         line_opacity=.3,
         line_curve=.7,
         line_type='dotted',  # 线的类型，有'solid', 'dashed', 'dotted'可选。默认为'solid'
         line_color='green',
        )
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shine': '/nbextensions/echarts-themes-js/shine'
#         }
#     });
# </script>
#     <div id="5f2f93b01306432d92ea5f0226304c85" style="width:1200px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'shine'], function(echarts) {
#
# var myChart_5f2f93b01306432d92ea5f0226304c85 = echarts.init(document.getElementById('5f2f93b01306432d92ea5f0226304c85'), 'shine', {renderer: 'canvas'});
#
# var option_5f2f93b01306432d92ea5f0226304c85 = {
#     "tooltip": {
#         "borderColor": "#333",
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderWidth": 0,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "trigger": "item",
#         "axisPointer": {
#             "type": "line"
#         },
#         "triggerOn": "mousemove|click"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "nameLocation": "middle",
#             "name": "\u5468\u6570",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": 2,
#                 "rotate": 30,
#                 "margin": 10,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "show": true,
#             "boundaryGap": true,
#             "nameTextStyle": {
#                 "fontSize": 16
#             },
#             "data": [
#                 "1\u5468",
#                 "2\u5468",
#                 "3\u5468",
#                 "4\u5468",
#                 "5\u5468",
#                 "6\u5468",
#                 "7\u5468",
#                 "8\u5468",
#                 "9\u5468",
#                 "10\u5468",
#                 "11\u5468",
#                 "12\u5468",
#                 "13\u5468",
#                 "14\u5468",
#                 "15\u5468",
#                 "16\u5468",
#                 "17\u5468",
#                 "18\u5468",
#                 "19\u5468",
#                 "20\u5468",
#                 "21\u5468",
#                 "22\u5468",
#                 "23\u5468",
#                 "24\u5468",
#                 "25\u5468",
#                 "26\u5468",
#                 "27\u5468",
#                 "28\u5468",
#                 "29\u5468",
#                 "30\u5468",
#                 "31\u5468",
#                 "32\u5468",
#                 "33\u5468",
#                 "34\u5468",
#                 "35\u5468",
#                 "36\u5468",
#                 "37\u5468",
#                 "38\u5468",
#                 "39\u5468",
#                 "40\u5468",
#                 "41\u5468",
#                 "42\u5468",
#                 "43\u5468",
#                 "44\u5468",
#                 "45\u5468",
#                 "46\u5468",
#                 "47\u5468",
#                 "48\u5468",
#                 "49\u5468",
#                 "50\u5468",
#                 "51\u5468",
#                 "52\u5468"
#             ],
#             "inverse": false,
#             "nameGap": 35,
#             "splitLine": {
#                 "show": false
#             }
#         }
#     ],
#     "legend": [
#         {
#             "left": "center",
#             "selectedMode": "multiple",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u7d2f\u8ba1\u6536\u76ca"
#             ],
#             "show": true,
#             "top": "top"
#         }
#     ],
#     "title": [
#         {
#             "left": "auto",
#             "text": "\u7d2f\u8ba1\u6536\u76ca\u56fe",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "subtext": "--\u4e3a\u6d4b\u8bd5\u901a\u7528\u914d\u7f6e\u9879\u53c2\u6570",
#             "top": "auto"
#         }
#     ],
#     "dataZoom": [
#         {
#             "type": "slider",
#             "orient": "horizontal",
#             "end": 50,
#             "show": true,
#             "start": 20
#         },
#         {
#             "type": "inside",
#             "orient": "horizontal",
#             "end": 50,
#             "show": true,
#             "start": 20
#         }
#     ],
#     "toolbox": {
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "magicType": {
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "show": true,
#                 "title": {
#                     "line": "\u6298\u7ebf\u56fe",
#                     "stack": "\u5806\u53e0",
#                     "tiled": "\u5e73\u94fa",
#                     "bar": "\u67f1\u72b6\u56fe"
#                 }
#             },
#             "dataView": {
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "back": "\u7f29\u653e\u8fd8\u539f",
#                     "zoom": "\u533a\u57df\u7f29\u653e"
#                 }
#             }
#         },
#         "orient": "vertical",
#         "show": true,
#         "top": "center"
#     },
#     "color": [],
#     "yAxis": [
#         {
#             "type": "value",
#             "inverse": false,
#             "nameLocation": "middle",
#             "nameTextStyle": {
#                 "fontSize": 16
#             },
#             "name": "\u7d2f\u8ba1\u6536\u76ca",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameGap": 50,
#             "splitLine": {
#                 "show": false
#             }
#         }
#     ],
#     "series": [
#         {
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "type": "line",
#             "markLine": {
#                 "data": []
#             },
#             "symbol": "emptyCircle",
#             "name": "\u7d2f\u8ba1\u6536\u76ca",
#             "symbolSize": 4,
#             "lineStyle": {
#                 "normal": {
#                     "type": "dotted",
#                     "color": "green",
#                     "opacity": 0.3,
#                     "width": 5,
#                     "curveness": 0.7
#                 }
#             },
#             "seriesId": 7901425,
#             "showSymbol": true,
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "data": [
#                 247.0,
#                 757.0,
#                 1069.0,
#                 1488.0,
#                 2082.0,
#                 2691.0,
#                 3377.0,
#                 4247.0,
#                 4837.0,
#                 4939.0,
#                 5926.0,
#                 6334.0,
#                 6578.0,
#                 7081.0,
#                 7526.0,
#                 7833.0,
#                 8558.0,
#                 9265.0,
#                 10139.0,
#                 10618.0,
#                 11037.0,
#                 11176.0,
#                 11297.0,
#                 11439.0,
#                 11643.0,
#                 11965.0,
#                 12330.0,
#                 12684.0,
#                 13217.0,
#                 13526.0,
#                 13905.0,
#                 14235.0,
#                 15034
