# %% [markdown]
# # 柱状图/条形图(Bar)

# %% [markdown]
# 柱状/条形图，通过柱形的高度/条形的宽度来表现数据的大小。

# %% [markdown]
# 展示多个分类的数据变化和同类别各变量之间的比较情况。
# * 适用：对比分类数据。
# * 局限：分类过多则无法展示数据特点。
# * 相似图表：
#     1. 堆积柱状图。比较同类别各变量和不同类别变量总和差异。
#     2. 百分比堆积柱状图。适合展示同类别的每个变量的比例。

# %%
# 导入柱状图类
from pyecharts import Bar

attr = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
v1 = [23.0, 44.9, 57.0, 23.2, 25.6, 46.7, 35.6, 62.2, 32.6, 20.0, 36.4, 3.3]

bar = Bar("Sales of XPS in 2017(million $)")
bar.add("XPS", attr, v1)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b43aec201a5a4a4986a28f23927294ec" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b43aec201a5a4a4986a28f23927294ec = echarts.init(document.getElementById('b43aec201a5a4a4986a28f23927294ec'), 'light', {renderer: 'canvas'});
#
# var option_b43aec201a5a4a4986a28f23927294ec = {
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 23.0,
#                 44.9,
#                 57.0,
#                 23.2,
#                 25.6,
#                 46.7,
#                 35.6,
#                 62.2,
#                 32.6,
#                 20.0,
#                 36.4,
#                 3.3
#             ],
#             "name": "XPS",
#             "type": "bar",
#             "seriesId": 7969094,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "series_id": 7969094,
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "title": [
#         {
#             "text": "Sales of XPS in 2017(million $)",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "top": "top",
#             "show": true,
#             "left": "center",
#             "data": [
#                 "XPS"
#             ]
#         }
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "nameGap": 25
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "nameGap": 25
#         }
#     ]
# };
# myChart_b43aec201a5a4a4986a28f23927294ec.setOption(option_b43aec201a5a4a4986a28f23927294ec);
#
#     });
# </script>

# %%
# 导入柱状图类
from pyecharts import Bar

attr = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
v1 = [23.0, 44.9, 57.0, 23.2, 25.6, 46.7, 35.6, 62.2, 32.6, 20.0, 36.4, 33.3]
v2 = [22.6, 45.9, 59.0, 26.4, 28.7, 50.7, 75.6, 82.2, 48.7, 18.8, 36.0, 2.3]

bar = Bar("Bar chart", "Sales of XPS and Alienware in 2017(million $)")
bar.add("XPS", attr, v1, mark_line=["average"], mark_point=["max", "min"])
bar.add("Alienware", attr, v2, mark_line=["average"], mark_point=["max", "min"])
bar.render(path='Bar charts - Sales of XPS and Alienware in 2017(million $).html')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6eb2a90ed5cb440ab61357311127095e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6eb2a90ed5cb440ab61357311127095e = echarts.init(document.getElementById('6eb2a90ed5cb440ab61357311127095e'), 'light', {renderer: 'canvas'});
#
# var option_6eb2a90ed5cb440ab61357311127095e = {
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 23.0,
#                 44.9,
#                 57.0,
#                 23.2,
#                 25.6,
#                 46.7,
#                 35.6,
#                 62.2,
#                 32.6,
#                 20.0,
#                 36.4,
#                 33.3
#             ],
#             "name": "XPS",
#             "type": "bar",
#             "seriesId": 1090404,
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "name": "mean-Value",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "name": "Maximum",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "name": "Minimum",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         },
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 22.6,
#                 45.9,
#                 59.0,
#                 26.4,
#                 28.7,
#                 50.7,
#                 75.6,
#                 82.2,
#                 48.7,
#                 18.8,
#                 36.0,
#                 2.3
#             ],
#             "name": "Alienware",
#             "type": "bar",
#             "seriesId": 1090404,
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "name": "mean-Value",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "name": "Maximum",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         "type": "min",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "name": "Minimum",
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "series_id": 1090404,
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "title": [
#         {
#             "text": "Bar chart",
#             "subtext": "Sales of XPS and Alienware in 2017(million $)",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "top": "top",
#             "show": true,
#             "left": "center",
#             "data": [
#                 "XPS",
#                 "Alienware"
#             ]
#         }
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "nameGap": 25
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },

# %% [markdown]
# add(name, x_axis, y_axis,
#     is_stack=False,
#     bar_category_gap='20%', **kwargs)
#
# name -> str
# 图例名称
# x_axis -> list
# x 坐标轴数据
# y_axis -> list
# y 坐标轴数据
# is_stack -> bool
# 数据堆叠，同个类目轴上系列配置相同的 stack 值可以堆叠放置
# bar_category_gap -> int/str
# 类目轴的柱状距离，当设置为 0 时柱状是紧挨着（直方图类型），默认为 '20%'

# %%
# 导入柱状图类
from pyecharts import Bar

attr = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
v1 = [23.0, 44.9, 57.0, 23.2, 25.6, 46.7, 35.6, 62.2, 32.6, 20.0, 36.4, 3.3]
v2 = [22.6, 45.9, 59.0, 26.4, 28.7, 50.7, 75.6, 82.2, 48.7, 18.8, 36.0, 2.3]

bar = Bar("Bar chart", "Sales of XPS and Alienware in 2017(million $)")
bar.add("XPS", attr, v1, mark_line=["average"], is_stack=True)
bar.add("Alienware", attr, v2, mark_line=["average"], is_stack=True)
bar.render(path='Bar charts - Sales of XPS and Alienware in 2017(million $).html')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e72e9c19bd2d4fd59712a22a5804618f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e72e9c19bd2d4fd59712a22a5804618f = echarts.init(document.getElementById('e72e9c19bd2d4fd59712a22a5804618f'), 'light', {renderer: 'canvas'});
#
# var option_e72e9c19bd2d4fd59712a22a5804618f = {
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 23.0,
#                 44.9,
#                 57.0,
#                 23.2,
#                 25.6,
#                 46.7,
#                 35.6,
#                 62.2,
#                 32.6,
#                 20.0,
#                 36.4,
#                 3.3
#             ],
#             "name": "XPS",
#             "stack": "stack_5593789",
#             "type": "bar",
#             "seriesId": 5593789,
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "name": "mean-Value",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         },
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 22.6,
#                 45.9,
#                 59.0,
#                 26.4,
#                 28.7,
#                 50.7,
#                 75.6,
#                 82.2,
#                 48.7,
#                 18.8,
#                 36.0,
#                 2.3
#             ],
#             "name": "Alienware",
#             "stack": "stack_5593789",
#             "type": "bar",
#             "seriesId": 5593789,
#             "markLine": {
#                 "symbolSize": 10,
#                 "data": [
#                     {
#                         "name": "mean-Value",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "series_id": 5593789,
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "title": [
#         {
#             "text": "Bar chart",
#             "subtext": "Sales of XPS and Alienware in 2017(million $)",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "top": "top",
#             "show": true,
#             "left": "center",
#             "data": [
#                 "XPS",
#                 "Alienware"
#             ]
#         }
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "nameGap": 25
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "nameGap": 25
#         }
#     ]
# };
# myChart_e72e9c19bd2d4fd59712a22a5804618f.setOption(option_e72e9c19bd2d4fd59712a22a5804618f);
#
#     });
# </script>

# %% [markdown]
# 当我们类目名称比较长的时候，我们会做条形图

# %%
bar = Bar("x 轴和 y 轴交换")
bar.add("商家A", attr, v1)
bar.add("商家B", attr, v2, is_convert=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="9f1f877345da42f08943075420052ae0" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_9f1f877345da42f08943075420052ae0 = echarts.init(document.getElementById('9f1f877345da42f08943075420052ae0'), 'light', {renderer: 'canvas'});
#
# var option_9f1f877345da42f08943075420052ae0 = {
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 23.0,
#                 44.9,
#                 57.0,
#                 23.2,
#                 25.6,
#                 46.7,
#                 35.6,
#                 62.2,
#                 32.6,
#                 20.0,
#                 36.4,
#                 3.3
#             ],
#             "name": "\u5546\u5bb6A",
#             "type": "bar",
#             "seriesId": 8008041,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         },
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 22.6,
#                 45.9,
#                 59.0,
#                 26.4,
#                 28.7,
#                 50.7,
#                 75.6,
#                 82.2,
#                 48.7,
#                 18.8,
#                 36.0,
#                 2.3
#             ],
#             "name": "\u5546\u5bb6B",
#             "type": "bar",
#             "seriesId": 8008041,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "series_id": 8008041,
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "title": [
#         {
#             "text": "x \u8f74\u548c y \u8f74\u4ea4\u6362",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "top": "top",
#             "show": true,
#             "left": "center",
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ]
#         }
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "nameGap": 25
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "category",
#             "splitLine": {
#                 "show": true
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "data": [
#                 "Jan",
#                 "Feb",
#                 "Mar",
#                 "Apr",
#                 "May",
#                 "Jun",
#                 "Jul",
#                 "Aug",
#                 "Sep",
#                 "Oct",
#                 "Nov",
#                 "Dec"
#             ],
#             "nameGap": 25
#         }
#     ]
# };
# myChart_9f1f877345da42f08943075420052ae0.setOption(option_9f1f877345da42f08943075420052ae0);
#
#     });
# </script>

# %%
import random

attr = ["{}天".format(i) for i in range(30)]
v1 = [random.randint(1, 30) for _ in range(30)]
bar = Bar("Bar - datazoom - slider 示例", width=1000)
bar.add("", attr, v1, is_label_show=True, is_datazoom_show=True)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="25007f870ee0456e9bf36950aabd1c06" style="width:1000px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_25007f870ee0456e9bf36950aabd1c06 = echarts.init(document.getElementById('25007f870ee0456e9bf36950aabd1c06'), 'light', {renderer: 'canvas'});
#
# var option_25007f870ee0456e9bf36950aabd1c06 = {
#     "series": [
#         {
#             "barCategoryGap": "20%",
#             "data": [
#                 12,
#                 28,
#                 20,
#                 4,
#                 7,
#                 27,
#                 12,
#                 4,
#                 29,
#                 30,
#                 14,
#                 22,
#                 20,
#                 6,
#                 12,
#                 1,
#                 5,
#                 7,
#                 13,
#                 16,
#                 6,
#                 22,
#                 20,
#                 17,
#                 9,
#                 22,
#                 13,
#                 18,
#                 20,
#                 19
#             ],
#             "type": "bar",
#             "seriesId": 2982584,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "series_id": 2982584,
#     "xAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ],
#             "nameGap": 25
#         }
#     ],
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "title": [
#         {
#             "text": "Bar - datazoom - slider \u793a\u4f8b",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "top": "top",
#             "show": true,
#             "left": "center",
#             "data": [
#                 ""
#             ]
#         }
#     ],
#     "dataZoom": [
#         {
#             "start": 50,
#             "end": 100,
#             "show": true,
#             "orient": "horizontal",
#             "type": "slider"
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "yAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "nameGap": 25
#         }
#     ]
# };
# myChart_25007f870ee0456e9bf36950aabd1c06.setOption(option_25007f870ee0456e9bf36950aabd1c06);
#
#     });
# </script>

# %% [markdown]
# ### 瀑布图
# * 适用场景：采用绝对值与相对值结合的方式，适用于表达数个特定数值之间的数量变化关系，最终展示一个累计值。
# * 优势：展示两个数据点之间的演变过程，还可以展示数据是如何累计的。
# * 劣势：没有柱状图、条形图的使用场景多。

# %%
from pyecharts import Bar

attr = ['IOS','Mac OS x','Android','Window 7', 'Window 8','Window 10','累计值']
v1 = [0, 100, 300, 650, 1450, 1650, 0]
v2 = [100, 200, 350, 800, 200, 200, 1850]
bar = Bar("过去一周用户操作系统偏好","瀑布图")
# 利用第一个 add() 图例的颜色为透明，即 'rgba(0,0,0,0)'，并且设置 is_stack 标志为 True
bar.add("", attr, v1, label_color=['rgba(0,0,0,0)'], is_stack=True)
bar.add("", attr, v2, is_label_show=True, is_stack=True, label_pos='inside')
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="5b372d4dcba849599cd982c0c25598ef" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_5b372d4dcba849599cd982c0c25598ef = echarts.init(document.getElementById('5b372d4dcba849599cd982c0c25598ef'), 'light', {renderer: 'canvas'});
#
# var option_5b372d4dcba849599cd982c0c25598ef = {
#     "tooltip": {
#         "triggerOn": "mousemove|click",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "borderWidth": 0,
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "color": [
#         "rgba(0,0,0,0)",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "show": true,
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "dataView": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "title": "\u4e0b\u8f7d\u56fe\u7247",
#                 "show": true
#             },
#             "restore": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 822334,
#     "legend": [
#         {
#             "orient": "horizontal",
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "top": "top",
#             "left": "center",
#             "show": true,
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "left": "auto",
#             "text": "\u8fc7\u53bb\u4e00\u5468\u7528\u6237\u64cd\u4f5c\u7cfb\u7edf\u504f\u597d",
#             "subtext": "\u7011\u5e03\u56fe",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLabel": {
#                 "formatter": "{value} ",
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "rotate": 0
#             },
#             "nameLocation": "middle",
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "boundaryGap": true,
#             "show": true,
#             "inverse": false,
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ],
#     "series": [
#         {
#             "data": [
#                 0,
#                 100,
#                 300,
#                 650,
#                 1450,
#                 1650,
#                 0
#             ],
#             "type": "bar",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "stack": "stack_822334",
#             "seriesId": 822334,
#             "barCategoryGap": "20%",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             }
#         },
#         {
#             "data": [
#                 100,
#                 200,
#                 350,
#                 800,
#                 200,
#                 200,
#                 1850
#             ],
#             "type": "bar",
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "position": "inside",
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "stack": "stack_822334",
#             "seriesId": 822334,
#             "barCategoryGap": "20%",
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             }
#         }
#     ],
#     "xAxis": [
#         {
#             "axisLabel": {
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "rotate": 0
#             },
#             "data": [
#                 "IOS",
#                 "Mac OS x",
#                 "Android",
#                 "Window 7",
#                 "Window 8",
#                 "Window 10",
#                 "\u7d2f\u8ba1\u503c"
#             ],
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "boundaryGap": true,
#             "show": true,
#             "nameLocation": "middle",
#             "inverse": false,
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             }
#         }
#     ]
# };
# myChart_5b372d4dcba849599cd982c0c25598ef.setOption(option_5b372d4dcba849599cd982c0c25598ef);
#
#     });
# </script>

# %% [markdown]
# ### 直方图

# %%
import pandas as pd
import numpy as np

ages = np.random.normal(10,1,size=10000)
bins = np.arange(6,14,0.1)  # bins 必须单调递增
# 以bins每个元素做分割点，分箱
cats = pd.cut(ages, bins)
data = pd.value_counts(cats).sort_index()

# %%
min(ages),max(ages)
# Out:
# (6.307831760532157, 13.605225306256697)

# %%
# 导入柱状图类
from pyecharts import Bar

bar = Bar("直方图")
bar.add("", data.index, data.values, bar_category_gap=0)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2a6535c5b883495ca7dcba48ac1e9d60" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2a6535c5b883495ca7dcba48ac1e9d60 = echarts.init(document.getElementById('2a6535c5b883495ca7dcba48ac1e9d60'), 'light', {renderer: 'canvas'});
#
# var option_2a6535c5b883495ca7dcba48ac1e9d60 = {
#     "series": [
#         {
#             "barCategoryGap": 0,
#             "data": [
#                 1.0,
#                 0.0,
#                 0.0,
#                 2.0,
#                 3.0,
#                 2.0,
#                 1.0,
#                 3.0,
#                 1.0,
#                 1.0,
#                 9.0,
#                 14.0,
#                 16.0,
#                 5.0,
#                 15.0,
#                 16.0,
#                 26.0,
#                 40.0,
#                 33.0,
#                 48.0,
#                 46.0,
#                 70.0,
#                 81.0,
#                 96.0,
#                 126.0,
#                 145.0,
#                 168.0,
#                 159.0,
#                 231.0,
#                 255.0,
#                 251.0,
#                 296.0,
#                 321.0,
#                 334.0,
#                 356.0,
#                 364.0,
#                 346.0,
#                 428.0,
#                 408.0,
#                 376.0,
#                 383.0,
#                 372.0,
#                 389.0,
#                 358.0,
#                 382.0,
#                 309.0,
#                 308.0,
#                 289.0,
#                 274.0,
#                 247.0,
#                 212.0,
#                 209.0,
#                 170.0,
#                 160.0,
#                 145.0,
#                 119.0,
#                 106.0,
#                 87.0,
#                 88.0,
#                 59.0,
#                 55.0,
#                 34.0,
#                 30.0,
#                 34.0,
#                 20.0,
#                 20.0,
#                 8.0,
#                 10.0,
#                 9.0,
#                 6.0,
#                 4.0,
#                 4.0,
#                 0.0,
#                 3.0,
#                 1.0,
#                 1.0,
#                 1.0,
#                 0.0,
#                 1.0
#             ],
#             "type": "bar",
#             "seriesId": 8167901,
#             "markLine": {
#                 "data": []
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "label": {
#                 "normal": {
#                     "position": "top",
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             }
#         }
#     ],
#     "series_id": 8167901,
#     "tooltip": {
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderColor": "#333",
#         "trigger": "item",
#         "borderWidth": 0,
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)"
#     },
#     "title": [
#         {
#             "text": "\u76f4\u65b9\u56fe",
#             "top": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto"
#         }
#     ],
#     "legend": [
#         {
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "selectedMode": "multiple",
#             "top": "top",
#             "show": true,
#             "left": "center",
#             "data": [
#                 ""
#             ]
#         }
#     ],
#     "xAxis": [
#         {
#             "inverse": false,
#             "nameLocation": "middle",
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "boundaryGap": true,
#             "show": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "(6.0, 6.1]",
#                 "(6.1, 6.2]",
#                 "(6.2, 6.3]",
#                 "(6.3, 6.4]",
#                 "(6.4, 6.5]",
#                 "(6.5, 6.6]",
#                 "(6.6, 6.7]",
#                 "(6.7, 6.8]",
#                 "(6.8, 6.9]",
#                 "(6.9, 7.0]",
#                 "(7.0, 7.1]",
#                 "(7.1, 7.2]",
#                 "(7.2, 7.3]",
#                 "(7.3, 7.4]",
#                 "(7.4, 7.5]",
#                 "(7.5, 7.6]",
#                 "(7.6, 7.7]",
#                 "(7.7, 7.8]",
#                 "(7.8, 7.9]",
#                 "(7.9, 8.0]",
#                 "(8.0, 8.1]",
#                 "(8.1, 8.2]",
#                 "(8.2, 8.3]",
#                 "(8.3, 8.4]",
#                 "(8.4, 8.5]",
#                 "(8.5, 8.6]",
#                 "(8.6, 8.7]",
#                 "(8.7, 8.8]",
#                 "(8.8, 8.9]",
#                 "(8.9, 9.0]",
#                 "(9.0, 9.1]",
#                 "(9.1, 9.2]",
#                 "(9.2, 9.3]",
#                 "(9.3, 9.4]",
#                 "(9.4, 9.5]",
#                 "(9.5, 9.6]",
#                 "(9.6, 9.7]",
#                 "(9.7, 9.8]",
#                 "(9.8, 9.9]",
#                 "(9.9, 10.0]",
#                 "(10.0, 10.1]",
#                 "(10.1, 10.2]",
#                 "(10.2, 10.3]",
#                 "(10.3, 10.4]",
#                 "(10.4, 10.5]",
#                 "(10.5, 10.6]",
#                 "(10.6, 10.7]",
#                 "(10.7, 10.8]",
#                 "(10.8, 10.9]",
#                 "(10.9, 11.0]",
#                 "(11.0, 11.1]",
#                 "(11.1, 11.2]",
#                 "(11.2, 11.3]",
#                 "(11.3, 11.4]",
#                 "(11.4, 11.5]",
#                 "(11.5, 11.6]",
#                 "(11.6, 11.7]",
#                 "(11.7, 11.8]",
#                 "(11.8, 11.9]",
#                 "(11.9, 12.0]",
#                 "(12.0, 12.1]",
#                 "(12.1, 12.2]",
#                 "(12.2, 12.3]",
#                 "(12.3, 12.4]",
#                 "(12.4, 12.5]",
#                 "(12.5, 12.6]",
#                 "(12.6, 12.7]",
#                 "(12.7, 12.8]",
#                 "(12.8, 12.9]",
#                 "(12.9, 13.0]",
#                 "(13.0, 13.1]",
#                 "(13.1, 13.2]",
#                 "(13.2, 13.3]",
#                 "(13.3, 13.4]",
#                 "(13.4, 13.5]",
#                 "(13.5, 13.6]",
#                 "(13.6, 13.7]",
#                 "(13.7, 13.8]",
#                 "(13.8, 13.9]"
#             ],
#             "nameGap": 25
#         }
#     ],
#     "toolbox": {
#         "orient": "vertical",
#         "top": "center",
#         "show": true,
#         "left": "95%",
#         "feature": {
#             "restore": {
#                 "show": true
#             },
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "
